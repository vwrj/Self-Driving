# %%
import os
import random
import math
import kornia
import numpy as np
import pandas as pd
import pdb
from collections import OrderedDict
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import collections  as mc
matplotlib.rcParams['figure.figsize'] = [6, 6]
matplotlib.rcParams['figure.dpi'] = 200

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms

from data_helper import UnlabeledDataset, LabeledDataset
from helper import draw_box

# random.seed(0)
# np.random.seed(0)
# torch.manual_seed(0);

# All the images are saved in image_folder
# All the labels are saved in the annotation_csv file
image_folder = '/scratch/brs426/data'
annotation_csv = '/scratch/brs426/data/annotation.csv'

# You shouldn't change the unlabeled_scene_index
# The first 106 scenes are unlabeled
unlabeled_scene_index = np.arange(106)
# The scenes from 106 - 133 are labeled
# You should devide the labeled_scene_index into two subsets (training and validation)
train_labeled_scene_index = np.arange(106, 132)
val_labeled_scene_index = np.arange(132, 134)
test_labeled_scene_index = np.arange(132, 134)

from helper import compute_ats_bounding_boxes, compute_ts_road_map

from math import acos
from math import sqrt
from math import pi

# %%
def length(v):
    return sqrt(v[0]**2+v[1]**2)

def dot_product(v,w):
    return v[0]*w[0]+v[1]*w[1]

def determinant(v,w):
    return v[0]*w[1]-v[1]*w[0]

def inner_angle(v,w):
    cosx=dot_product(v,w)/(length(v)*length(w))
    rad=acos(cosx) # in radians
    return rad*180/pi # returns degrees

def angle_clockwise(A, B):
    inner=inner_angle(A,B)
    det = determinant(A,B)
    if det<0: #this is a property of the det. If the det < 0 then B is clockwise of A
        return inner
    else: # if the det > 0 then A is immediately clockwise of B
        return 360-inner

# %%
def within_angles(xs, ys, angle1 = 274, angle2 = 330):
    '''
    xs and ys must be corresponding coordinates in matplotlib-space (y-axis 0 starts from the top).
    '''
    
    # Matplotlib y-axis -- 0 starts from the top, so we need to adjust. 
    v0 = np.array([xs[0] - 400, 800 - ys[0] - 400])
    v1 = np.array([xs[1] - 400, 800 - ys[1] - 400])
    v2 = np.array([xs[2] - 400, 800 - ys[2] - 400])
    v3 = np.array([xs[3] - 400, 800 - ys[3] - 400])
    v_ref = np.array([2, 0])
    
    condition = (angle_clockwise(v_ref, v0) >= angle1 and angle_clockwise(v_ref, v0) <= angle2) or \
                (angle_clockwise(v_ref, v1) >= angle1 and angle_clockwise(v_ref, v1) <= angle2) or \
                (angle_clockwise(v_ref, v2) >= angle1 and angle_clockwise(v_ref, v2) <= angle2) or \
                (angle_clockwise(v_ref, v3) >= angle1 and angle_clockwise(v_ref, v3) <= angle2)
    return condition

# %%
VERT_BLOCK_SIZE = 10
HORIZ_BLOCK_SIZE = 10
BLOCK_AREA = VERT_BLOCK_SIZE * HORIZ_BLOCK_SIZE

# %%
def blur(img):
    img = img.unsqueeze(0)
    blurred = kornia.filters.gaussian_blur2d(img, kernel_size=(5, 5), sigma=(9.5, 9.5))
    return blurred.squeeze(0)

# %%
def collate_fn(batch):
    left_images = []
    target = []
    road_maps = []
    bbox_maps = []
    bbox_bins = []
    bbs = []
    target_counts = []
    for x in batch:
        
        # Get road_image and cast it to float
        road_image = torch.as_tensor(x[2]).float()
        road_maps.append(road_image)
        
        # Collect six images for this sample. 
        # TODO: Try cutting off the top 100 pixels (that can lead to overfitting)
        image = torch.Tensor(x[0][0])[:, 130:, :]
        left_images.append(image)
        
        # target
        bb_tens = x[1]['bounding_box']
        current_bbs = []
        bbox_map = torch.zeros((800, 800))
        counts = np.zeros(8)
        count = 0
        
        # Create the bounding box map. 
        for i, corners in enumerate(bb_tens):
            
            # Grab the current bounding box. 
            current_bbs.append(corners)
            
            # Get its four bird's-eye view coordinates. 
            point_squence = torch.stack([corners[:, 0], corners[:, 1], corners[:, 3], corners[:, 2]])
            xs = point_squence.T[0] * 10 + 400
            ys = -point_squence.T[1] * 10 + 400
            
            # xs is horizontal, ys is vertical through. 
            # But we're doing things row, column way. 
            
            # Only get the bounding boxes that are close-by. On the same road. 
            # We want to see if the model can fucking predict cars that are close by. 
            
            center_x, center_y = torch.mean(xs).item(), torch.mean(ys).item()
            if within_angles(xs, ys) and center_y > 285 and center_y < 525:
            
                # Grab the top-left coordinates. 
                r, c = int(torch.min(ys).item()), int(torch.min(xs).item())
                r_len, c_len = int(torch.max(ys).item()) - r, int(torch.max(xs).item()) - c

                # Fill in the bbox. 
                bbox_map[r:r+r_len, c:c+c_len] = 1.0

                count += 1
            
        # Convert the bounding box map into classes (5px by 5px bins)
        bbox_grid = []
        for x_ in range(0, 800, VERT_BLOCK_SIZE):
            for y in range(0, 800, HORIZ_BLOCK_SIZE):
                block = bbox_map[x_:x_+VERT_BLOCK_SIZE, y:y+HORIZ_BLOCK_SIZE]
                score = torch.sum(block).item()
                # If more than have the pixels are 1, classify as bbox car
                if score > 0.5 * (BLOCK_AREA):
                    bbox_grid.append(1.0)
                else:
                    bbox_grid.append(0.0)
                    
        bbox_bins.append(torch.Tensor(bbox_grid))
              
        counts[count] = 1

        # Label Smoothing #
#         if count > 15 and count < 88:
#             counts[count+1] = 0.2
#             counts[count-1] = 0.2
            
        target_counts.append(torch.Tensor(counts))
        
        bbox_maps.append(bbox_map)

        bbs.append(current_bbs)
                
    boom = torch.stack(left_images), torch.stack(bbox_bins), torch.stack(road_maps), bbs, torch.stack(target_counts), torch.stack(bbox_maps) 
    return boom

# %%
val_transform = transforms.ToTensor()

train_transform = transforms.Compose([
    transforms.ColorJitter(brightness = 0.5, contrast = 0.5, saturation = 0.4, hue = (-0.5, 0.5)),
    transforms.RandomApply([
        transforms.Grayscale(3),
#         transforms.RandomAffine(1),
    ]),
    transforms.ToTensor(),
    transforms.RandomApply([
        transforms.Lambda(lambda img: blur(img)),
    ])
])

labeled_trainset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=train_labeled_scene_index,
                                  transform=train_transform,
                                  extra_info=True
                                 )

labeled_valset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=val_labeled_scene_index,
                                  transform=val_transform,
                                  extra_info=True
                                 )

# %% [markdown]
# #### Testing

# %%
train_loader = torch.utils.data.DataLoader(labeled_trainset, batch_size=16, shuffle=True, collate_fn=collate_fn)

# %%
# Compute threat scores
def reconstruct_from_bins(bins, threshold):
    print(bins.shape)
    road_map = torch.zeros((800, 800))
    idx = 0
    for x in range(0, 800, VERT_BLOCK_SIZE):
        for y in range(0, 800, HORIZ_BLOCK_SIZE):
            road_map[x:x+VERT_BLOCK_SIZE, y:y+HORIZ_BLOCK_SIZE] = bins[idx]
            idx += 1
    return road_map > threshold

# %%
sample, bbox_bins, road_maps, bbs, counts, bbox_maps  = iter(train_loader).next()

# %%
idx = -1

# %%
idx += 1

# %%
print(torch.argmax(counts[idx]))
matplotlib.rcParams['figure.figsize'] = [5,5]
plt.imshow(sample[idx].numpy().transpose(1, 2, 0))
plt.axis('off');
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-143-113c470d450c> in <module>
# ----> 1 print(torch.argmax(counts[idx]))
#       2 matplotlib.rcParams['figure.figsize'] = [5,5]
#       3 plt.imshow(sample[idx].numpy().transpose(1, 2, 0))
#       4 plt.axis('off');
#
# IndexError: index 16 is out of bounds for dimension 0 with size 16

# %%
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [3,3]
fig, ax = plt.subplots()
ax.imshow(road_maps[idx], cmap ='binary');
ax.plot(400, 400, 'x', color="red")
for bb in bbs[idx]:
    draw_box(ax, bb, 'orange')

# %%
threshold = 0.5
road_map = reconstruct_from_bins(bbox_bins[idx], threshold)
fig, ax = plt.subplots()
ax.imshow(road_map, cmap ='binary');
ax.plot(400, 400, 'x', color="red")
# Out:
# torch.Size([6400])

# %% [markdown]
# ### Model

# %%
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        
        self.encoder = torchvision.models.resnet34()
        self.encoder.fc = nn.Identity()
        self.concat_dim = 100
        self.dropout = nn.Dropout(p = 0.2)
        self.bn = nn.BatchNorm1d(self.concat_dim)
        
        self.compress = nn.Sequential(OrderedDict([
            ('linear0', nn.Linear(512, 100)),
            ('relu', nn.ReLU()),
        ]))
        
        self.vehicle_map = nn.Sequential(OrderedDict([
            ('linear1_vehicle', nn.Linear(self.concat_dim, 6400)),
        ]))
        
        self.counts = nn.Sequential(OrderedDict([
            ('count1', nn.Linear(self.concat_dim, 8))
        ]))
        
    def forward(self, x):
        
        batch_size = x.shape[0]
        channels = x.shape[1]
        height = x.shape[2]
        width = x.shape[3]
        # Reshape here
        x = x.view(-1, channels, height, width)
        x = self.encoder(x)
        x = self.compress(x)
        x = x.view(-1, self.concat_dim)
        x = self.bn(x)
        x = self.dropout(x)
    
        return self.vehicle_map(x), self.counts(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleModel()
# model.load_state_dict(torch.load('/scratch/vr1059/left_image_checkpoint.pt'))
model = model.to(device)
map_criterion = nn.BCEWithLogitsLoss()
count_criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-4)
best_val_loss = 100

# %%
def train():
    model.train()
    labeled_trainset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=train_labeled_scene_index,
                                  transform=train_transform,
                                  extra_info=True
                                 )
    train_loader = torch.utils.data.DataLoader(labeled_trainset, batch_size=15, num_workers=15, shuffle=True, collate_fn=collate_fn)
    
    train_losses = []
    map_losses = []
    count_losses = []
    f = open(log_file_path, "a+")
    for i, (sample, bbox_bins, road_maps, bbs, target_count, _) in enumerate(train_loader):
        optimizer.zero_grad()

        sample = sample.to(device)
        bbox_bins = bbox_bins.to(device)
        target_count = target_count.to(device)
        
        y_vehicle, y_count = model(sample)
        
        map_loss = map_criterion(y_vehicle, bbox_bins.float())
        count_loss = count_criterion(y_count, target_count.float())
        loss = 0.99 * map_loss + 0.01 * count_loss
        
        loss.backward()
        optimizer.step()
        
        train_losses.append(loss.item())
        map_losses.append(map_loss.item())
        count_losses.append(count_loss.item())
        if i % 50 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, i * len(sample), len(train_loader.dataset),
                50. * i / len(train_loader), loss.item()))
            
    print("\nAverage Train Epoch Loss: ", np.mean(train_losses))
    print("Average Train Map Loss: ", np.mean(map_losses))
    print("Average Train Count Epoch Loss: ", np.mean(count_losses))
    
    f.write("\nAverage Train Epoch Loss: {}".format(np.mean(train_losses)))
    f.write("Average Train Map Loss: {}".format(np.mean(map_losses)))
    f.write("Average Train Count Epoch Loss: {}".format(np.mean(count_losses)))
    
    f.close()
    
            
def val():
    
    val_loader = torch.utils.data.DataLoader(labeled_valset, batch_size=15, num_workers=5, shuffle=True, collate_fn=collate_fn)
    model.eval()
    val_losses = []
    map_losses = []
    count_losses = []
    
    f = open(log_file_path, "a+")
    
    for i, (sample, bbox_bins, road_maps, bbs, target_count, _) in enumerate(val_loader):

        model.eval()

        sample = sample.to(device)
        bbox_bins = bbox_bins.to(device)
        target_count = target_count.to(device)

        with torch.no_grad():
            y_vehicle, y_count = model(sample)
        
            map_loss = map_criterion(y_vehicle, bbox_bins.float())
            count_loss = count_criterion(y_count, target_count.float())
            loss = 0.99 * map_loss + 0.01 * count_loss
            
            val_losses.append(loss.item())
            map_losses.append(map_loss.item())
            count_losses.append(count_loss.item())
            
    print("\tAverage Validation Epoch Loss: ", np.mean(val_losses))
    print("\tAverage Validation Map Epoch Loss: ", np.mean(map_losses))
    print("\tAverage Validation Count Epoch Loss: ", np.mean(count_losses))
    
    f.write("\nAverage Validation Epoch Loss: {}".format(np.mean(val_losses)))
    f.write("\tAverage Validation Map Epoch Loss: {}".format(np.mean(map_losses)))
    f.write("\tAverage Validation Count Epoch Loss: {}".format(np.mean(count_losses)))

    global best_val_loss
    if np.mean(map_losses) < best_val_loss:
        best_val_loss = np.mean(map_losses)
        f.write("\n best_val_loss so far: {}".format(best_val_loss))
        torch.save(model.state_dict(), '/scratch/vr1059/left_image_resnet34_10_by_10.pt')
        
    f.close()

# %%
log_file_path = "left_image_10_by_10.log"

# %%
epochs = 75
for epoch in range(epochs):
    train()
    val()
# Out:
# Train Epoch: 0 [0/3276 (0%)]	Loss: 0.728618
# Train Epoch: 0 [750/3276 (11%)]	Loss: 0.698608
# Train Epoch: 0 [1500/3276 (23%)]	Loss: 0.684193
# Train Epoch: 0 [2250/3276 (34%)]	Loss: 0.670215
# Train Epoch: 0 [3000/3276 (46%)]	Loss: 0.638018
#
# Average Train Epoch Loss:  0.6788754980313724
# Average Train Map Loss:  0.6788773925881407
# Average Train Count Epoch Loss:  0.6786875961578056
# 	Average Validation Epoch Loss:  0.6192284577033099
# 	Average Validation Map Epoch Loss:  0.6191177578533397
# 	Average Validation Count Epoch Loss:  0.6301885212168974
# Train Epoch: 1 [0/3276 (0%)]	Loss: 0.621306
# Train Epoch: 1 [750/3276 (11%)]	Loss: 0.582187
# Train Epoch: 1 [1500/3276 (23%)]	Loss: 0.537204
# Train Epoch: 1 [2250/3276 (34%)]	Loss: 0.485960
# Train Epoch: 1 [3000/3276 (46%)]	Loss: 0.421127
#
# Average Train Epoch Loss:  0.5234815270116885
# Average Train Map Loss:  0.5230645623109113
# Average Train Count Epoch Loss:  0.5647606880969653
# 	Average Validation Epoch Loss:  0.4289749492617214
# 	Average Validation Map Epoch Loss:  0.42817434142617616
# 	Average Validation Count Epoch Loss:  0.508234795402078
# Train Epoch: 2 [0/3276 (0%)]	Loss: 0.398857
# Train Epoch: 2 [750/3276 (11%)]	Loss: 0.333352
# Train Epoch: 2 [1500/3276 (23%)]	Loss: 0.279208
# Train Epoch: 2 [2250/3276 (34%)]	Loss: 0.231241
# Train Epoch: 2 [3000/3276 (46%)]	Loss: 0.223211
#
# Average Train Epoch Loss:  0.28969598639773453
# Average Train Map Loss:  0.288472769739421
# Average Train Count Epoch Loss:  0.41079417320146955
# 	Average Validation Epoch Loss:  0.19437955670496998
# 	Average Validation Map Epoch Loss:  0.19275376551291523
# 	Average Validation Count Epoch Loss:  0.35533272343523364
# Train Epoch: 3 [0/3276 (0%)]	Loss: 0.189840
# Train Epoch: 3 [750/3276 (11%)]	Loss: 0.166496
# Train Epoch: 3 [1500/3276 (23%)]	Loss: 0.148855
# Train Epoch: 3 [2250/3276 (34%)]	Loss: 0.105422
# Train Epoch: 3 [3000/3276 (46%)]	Loss: 0.096229
#
# Average Train Epoch Loss:  0.1393448901979346
# Average Train Map Loss:  0.13749804181051037
# Average Train Count Epoch Loss:  0.32218273058873875
# 	Average Validation Epoch Loss:  0.1043722309610423
# 	Average Validation Map Epoch Loss:  0.1024988657411407
# 	Average Validation Count Epoch Loss:  0.28983547407038074
# Train Epoch: 4 [0/3276 (0%)]	Loss: 0.088263
# Train Epoch: 4 [750/3276 (11%)]	Loss: 0.082715
# Train Epoch: 4 [1500/3276 (23%)]	Loss: 0.086326
# Train Epoch: 4 [2250/3276 (34%)]	Loss: 0.064917
# Train Epoch: 4 [3000/3276 (46%)]	Loss: 0.054787
#
# Average Train Epoch Loss:  0.07312935048110408
# Average Train Map Loss:  0.07097615126401322
# Average Train Count Epoch Loss:  0.28629600688747076
# 	Average Validation Epoch Loss:  0.053233472739948946
# 	Average Validation Map Epoch Loss:  0.05099943258306559
# 	Average Validation Count Epoch Loss:  0.2744034318362965
# Train Epoch: 5 [0/3276 (0%)]	Loss: 0.057173
# Train Epoch: 5 [750/3276 (11%)]	Loss: 0.046545
# Train Epoch: 5 [1500/3276 (23%)]	Loss: 0.045477
# Train Epoch: 5 [2250/3276 (34%)]	Loss: 0.035789
# Train Epoch: 5 [3000/3276 (46%)]	Loss: 0.038524
#
# Average Train Epoch Loss:  0.044948945136647246
# Average Train Map Loss:  0.04266377064701357
# Average Train Count Epoch Loss:  0.2711811978795213
# 	Average Validation Epoch Loss:  0.03472763562903685
# 	Average Validation Map Epoch Loss:  0.032403533073032606
# 	Average Validation Count Epoch Loss:  0.2648137150441899
# Train Epoch: 6 [0/3276 (0%)]	Loss: 0.036025
# Train Epoch: 6 [750/3276 (11%)]	Loss: 0.032622
# Train Epoch: 6 [1500/3276 (23%)]	Loss: 0.029254
# Train Epoch: 6 [2250/3276 (34%)]	Loss: 0.031786
# Train Epoch: 6 [3000/3276 (46%)]	Loss: 0.028406
#
# Average Train Epoch Loss:  0.03153349798529932
# Average Train Map Loss:  0.029149229446910833
# Average Train Count Epoch Loss:  0.26757604904370763
# 	Average Validation Epoch Loss:  0.025000782683491707
# 	Average Validation Map Epoch Loss:  0.022581979741944987
# 	Average Validation Count Epoch Loss:  0.26446227554012747
# Train Epoch: 7 [0/3276 (0%)]	Loss: 0.029344
# Train Epoch: 7 [750/3276 (11%)]	Loss: 0.024202
# Train Epoch: 7 [1500/3276 (23%)]	Loss: 0.021378
# Train Epoch: 7 [2250/3276 (34%)]	Loss: 0.023090
# Train Epoch: 7 [3000/3276 (46%)]	Loss: 0.022365
#
# Average Train Epoch Loss:  0.024112047100244047
# Average Train Map Loss:  0.021687198681204015
# Average Train Count Epoch Loss:  0.2641720244465353
# 	Average Validation Epoch Loss:  0.020282653105609557
# 	Average Validation Map Epoch Loss:  0.01783914491534233
# 	Average Validation Count Epoch Loss:  0.26218997205004974
# Train Epoch: 8 [0/3276 (0%)]	Loss: 0.021175
# Train Epoch: 8 [750/3276 (11%)]	Loss: 0.017511
# Train Epoch: 8 [1500/3276 (23%)]	Loss: 0.020054
# Train Epoch: 8 [2250/3276 (34%)]	Loss: 0.022074
# Train Epoch: 8 [3000/3276 (46%)]	Loss: 0.018319
#
# Average Train Epoch Loss:  0.019340073570745176
# Average Train Map Loss:  0.016869375460938505
# Average Train Count Epoch Loss:  0.2639391841409413
# 	Average Validation Epoch Loss:  0.01599963239448912
# 	Average Validation Map Epoch Loss:  0.013551300117636429
# 	Average Validation Count Epoch Loss:  0.2583845389239928
# Train Epoch: 9 [0/3276 (0%)]	Loss: 0.018027
# Train Epoch: 9 [750/3276 (11%)]	Loss: 0.016473
# Train Epoch: 9 [1500/3276 (23%)]	Loss: 0.017394
# Train Epoch: 9 [2250/3276 (34%)]	Loss: 0.015419
# Train Epoch: 9 [3000/3276 (46%)]	Loss: 0.012729
#
# Average Train Epoch Loss:  0.016057020372213567
# Average Train Map Loss:  0.013553901396895924
# Average Train Count Epoch Loss:  0.26386578455907567
# 	Average Validation Epoch Loss:  0.014040105099625447
# 	Average Validation Map Epoch Loss:  0.011585419175817686
# 	Average Validation Count Epoch Loss:  0.25705400459906635
# Train Epoch: 10 [0/3276 (0%)]	Loss: 0.014846
# Train Epoch: 10 [750/3276 (11%)]	Loss: 0.012495
# Train Epoch: 10 [1500/3276 (23%)]	Loss: 0.011963
# Train Epoch: 10 [2250/3276 (34%)]	Loss: 0.012538
# Train Epoch: 10 [3000/3276 (46%)]	Loss: 0.010753
#
# Average Train Epoch Loss:  0.014097600409837619
# Average Train Map Loss:  0.011589488977796002
# Average Train Count Epoch Loss:  0.26240062543518466
# 	Average Validation Epoch Loss:  0.012333612231647266
# 	Average Validation Map Epoch Loss:  0.009851382607046296
# 	Average Validation Count Epoch Loss:  0.2580743283033371
# Train Epoch: 11 [0/3276 (0%)]	Loss: 0.011930
# Train Epoch: 11 [750/3276 (11%)]	Loss: 0.012764
# Train Epoch: 11 [1500/3276 (23%)]	Loss: 0.015488
# Train Epoch: 11 [2250/3276 (34%)]	Loss: 0.012944
# Train Epoch: 11 [3000/3276 (46%)]	Loss: 0.009699
#
# Average Train Epoch Loss:  0.012767284283559072
# Average Train Map Loss:  0.010258851596260587
# Average Train Count Epoch Loss:  0.261102121578504
# 	Average Validation Epoch Loss:  0.011486601687091239
# 	Average Validation Map Epoch Loss:  0.00897909700870514
# 	Average Validation Count Epoch Loss:  0.2597295685726054
# Train Epoch: 12 [0/3276 (0%)]	Loss: 0.011904
# Train Epoch: 12 [750/3276 (11%)]	Loss: 0.012633
# Train Epoch: 12 [1500/3276 (23%)]	Loss: 0.012493
# Train Epoch: 12 [2250/3276 (34%)]	Loss: 0.011826
# Train Epoch: 12 [3000/3276 (46%)]	Loss: 0.013475
#
# Average Train Epoch Loss:  0.011669326190875
# Average Train Map Loss:  0.00916164007556697
# Average Train Count Epoch Loss:  0.2599302475855231
# 	Average Validation Epoch Loss:  0.010670420111102216
# 	Average Validation Map Epoch Loss:  0.008179451010244735
# 	Average Validation Count Epoch Loss:  0.25727637725717883
# Train Epoch: 13 [0/3276 (0%)]	Loss: 0.012614
# Train Epoch: 13 [750/3276 (11%)]	Loss: 0.012720
# Train Epoch: 13 [1500/3276 (23%)]	Loss: 0.014301
# Train Epoch: 13 [2250/3276 (34%)]	Loss: 0.012496
# Train Epoch: 13 [3000/3276 (46%)]	Loss: 0.010158
#
# Average Train Epoch Loss:  0.010905961795246492
# Average Train Map Loss:  0.008406057216005918
# Average Train Count Epoch Loss:  0.25839651229719046
# 	Average Validation Epoch Loss:  0.01004340422942358
# 	Average Validation Map Epoch Loss:  0.007559399038334103
# 	Average Validation Count Epoch Loss:  0.2559599140111138
# Train Epoch: 14 [0/3276 (0%)]	Loss: 0.009136
# Train Epoch: 14 [750/3276 (11%)]	Loss: 0.010460
# Train Epoch: 14 [1500/3276 (23%)]	Loss: 0.010193
# Train Epoch: 14 [2250/3276 (34%)]	Loss: 0.016181
# Train Epoch: 14 [3000/3276 (46%)]	Loss: 0.009922
#
# Average Train Epoch Loss:  0.010380997222563311
# Average Train Map Loss:  0.007888933114248188
# Average Train Count Epoch Loss:  0.2570953443306222
# 	Average Validation Epoch Loss:  0.009799219448776805
# 	Average Validation Map Epoch Loss:  0.007333764258553
# 	Average Validation Count Epoch Loss:  0.2538792832809336
# Train Epoch: 15 [0/3276 (0%)]	Loss: 0.008536
# Train Epoch: 15 [750/3276 (11%)]	Loss: 0.007324
# Train Epoch: 15 [1500/3276 (23%)]	Loss: 0.009333
# Train Epoch: 15 [2250/3276 (34%)]	Loss: 0.010645
# Train Epoch: 15 [3000/3276 (46%)]	Loss: 0.011545
#
# Average Train Epoch Loss:  0.009680049587466402
# Average Train Map Loss:  0.007280481119159626
# Average Train Count Epoch Loss:  0.2472373259394136
# 	Average Validation Epoch Loss:  0.008565137491506688
# 	Average Validation Map Epoch Loss:  0.006329601548392983
# 	Average Validation Count Epoch Loss:  0.22988318695741541
# Train Epoch: 16 [0/3276 (0%)]	Loss: 0.009022
# Train Epoch: 16 [750/3276 (11%)]	Loss: 0.010737
# Train Epoch: 16 [1500/3276 (23%)]	Loss: 0.008407
# Train Epoch: 16 [2250/3276 (34%)]	Loss: 0.009935
# Train Epoch: 16 [3000/3276 (46%)]	Loss: 0.008595
#
# Average Train Epoch Loss:  0.009108917974786126
# Average Train Map Loss:  0.006758500289248481
# Average Train Count Epoch Loss:  0.24180026821894188
# 	Average Validation Epoch Loss:  0.008610945249743322
# 	Average Validation Map Epoch Loss:  0.006264894981594647
# 	Average Validation Count Epoch Loss:  0.24086992793223438
# Train Epoch: 17 [0/3276 (0%)]	Loss: 0.008266
# Train Epoch: 17 [750/3276 (11%)]	Loss: 0.006969
# Train Epoch: 17 [1500/3276 (23%)]	Loss: 0.008253
# Train Epoch: 17 [2250/3276 (34%)]	Loss: 0.008073
# Train Epoch: 17 [3000/3276 (46%)]	Loss: 0.010334
#
# Average Train Epoch Loss:  0.008668636511926238
# Average Train Map Loss:  0.006389445409425386
# Average Train Count Epoch Loss:  0.23430855490573466
# 	Average Validation Epoch Loss:  0.008112705531804001
# 	Average Validation Map Epoch Loss:  0.0058612861971863925
# 	Average Validation Count Epoch Loss:  0.23100320907200084
# Train Epoch: 18 [0/3276 (0%)]	Loss: 0.009243
# Train Epoch: 18 [750/3276 (11%)]	Loss: 0.006701
# Train Epoch: 18 [1500/3276 (23%)]	Loss: 0.011838
# Train Epoch: 18 [2250/3276 (34%)]	Loss: 0.006814
# Train Epoch: 18 [3000/3276 (46%)]	Loss: 0.005682
#
# Average Train Epoch Loss:  0.008111506715399898
# Average Train Map Loss:  0.005914945528549078
# Average Train Count Epoch Loss:  0.22557106253491144
# 	Average Validation Epoch Loss:  0.007756970850202967
# 	Average Validation Map Epoch Loss:  0.005606471095234156
# 	Average Validation Count Epoch Loss:  0.22065644492121303
# Train Epoch: 19 [0/3276 (0%)]	Loss: 0.006624
# Train Epoch: 19 [750/3276 (11%)]	Loss: 0.006882
# Train Epoch: 19 [1500/3276 (23%)]	Loss: 0.006631
# Train Epoch: 19 [2250/3276 (34%)]	Loss: 0.007106
# Train Epoch: 19 [3000/3276 (46%)]	Loss: 0.006122
#
# Average Train Epoch Loss:  0.007876419024244291
# Average Train Map Loss:  0.005689867534015549
# Average Train Count Epoch Loss:  0.2243450166291842
# 	Average Validation Epoch Loss:  0.007700908189529882
# 	Average Validation Map Epoch Loss:  0.005544497563010629
# 	Average Validation Count Epoch Loss:  0.2211855667478898
# Train Epoch: 20 [0/3276 (0%)]	Loss: 0.008142
# Train Epoch: 20 [750/3276 (11%)]	Loss: 0.005728
# Train Epoch: 20 [1500/3276 (23%)]	Loss: 0.006519
# Train Epoch: 20 [2250/3276 (34%)]	Loss: 0.006638
# Train Epoch: 20 [3000/3276 (46%)]	Loss: 0.010324
#
# Average Train Epoch Loss:  0.007225652729250388
# Average Train Map Loss:  0.005197676840625261
# Average Train Count Epoch Loss:  0.20799526528000287
# 	Average Validation Epoch Loss:  0.00723378368489006
# 	Average Validation Map Epoch Loss:  0.005207099006785189
# 	Average Validation Count Epoch Loss:  0.2078755655709435
# Train Epoch: 21 [0/3276 (0%)]	Loss: 0.007861
# Train Epoch: 21 [750/3276 (11%)]	Loss: 0.004733
# Train Epoch: 21 [1500/3276 (23%)]	Loss: 0.007594
# Train Epoch: 21 [2250/3276 (34%)]	Loss: 0.006516
# Train Epoch: 21 [3000/3276 (46%)]	Loss: 0.006722
#
# Average Train Epoch Loss:  0.006913688252828845
# Average Train Map Loss:  0.005007253347398484
# Average Train Count Epoch Loss:  0.19565074292083853
# 	Average Validation Epoch Loss:  0.007182422422749155
# 	Average Validation Map Epoch Loss:  0.00511855778613073
# 	Average Validation Count Epoch Loss:  0.21150501335368438
# Train Epoch: 22 [0/3276 (0%)]	Loss: 0.009771
# Train Epoch: 22 [750/3276 (11%)]	Loss: 0.004477
# Train Epoch: 22 [1500/3276 (23%)]	Loss: 0.005168
# Train Epoch: 22 [2250/3276 (34%)]	Loss: 0.007827
# Train Epoch: 22 [3000/3276 (46%)]	Loss: 0.004719
#
# Average Train Epoch Loss:  0.006407234085230454
# Average Train Map Loss:  0.004666054270498148
# Average Train Count Epoch Loss:  0.1787840355544874
# 	Average Validation Epoch Loss:  0.006638781249742298
# 	Average Validation Map Epoch Loss:  0.004879618666189558
# 	Average Validation Count Epoch Loss:  0.18079588299288468
# Train Epoch: 23 [0/3276 (0%)]	Loss: 0.011517
# Train Epoch: 23 [750/3276 (11%)]	Loss: 0.005575
# Train Epoch: 23 [1500/3276 (23%)]	Loss: 0.007026
# Train Epoch: 23 [2250/3276 (34%)]	Loss: 0.004573
# Train Epoch: 23 [3000/3276 (46%)]	Loss: 0.005431
#
# Average Train Epoch Loss:  0.006090739281575905
# Average Train Map Loss:  0.0044608536170004575
# Average Train Count Epoch Loss:  0.1674494200373349
# 	Average Validation Epoch Loss:  0.006283813649240662
# 	Average Validation Map Epoch Loss:  0.004738072878407205
# 	Average Validation Count Epoch Loss:  0.15931215181070216
# Train Epoch: 24 [0/3276 (0%)]	Loss: 0.005719
# Train Epoch: 24 [750/3276 (11%)]	Loss: 0.004838
# Train Epoch: 24 [1500/3276 (23%)]	Loss: 0.004989
# Train Epoch: 24 [2250/3276 (34%)]	Loss: 0.003083
# Train Epoch: 24 [3000/3276 (46%)]	Loss: 0.004693
#
# Average Train Epoch Loss:  0.0057737838708663775
# Average Train Map Loss:  0.004219550959400186
# Average Train Count Epoch Loss:  0.15964284260251208
# 	Average Validation Epoch Loss:  0.00635948492323651
# 	Average Validation Map Epoch Loss:  0.004682055756668834
# 	Average Validation Count Epoch Loss:  0.17242496460676193
# Train Epoch: 25 [0/3276 (0%)]	Loss: 0.003590
# Train Epoch: 25 [750/3276 (11%)]	Loss: 0.004899
# Train Epoch: 25 [1500/3276 (23%)]	Loss: 0.003750
# Train Epoch: 25 [2250/3276 (34%)]	Loss: 0.005241
# Train Epoch: 25 [3000/3276 (46%)]	Loss: 0.005701
#
# Average Train Epoch Loss:  0.005526037894180853
# Average Train Map Loss:  0.004059180984120459
# Average Train Count Epoch Loss:  0.15074487183600255
# 	Average Validation Epoch Loss:  0.006121188320000382
# 	Average Validation Map Epoch Loss:  0.004499830100137521
# 	Average Validation Count Epoch Loss:  0.16663565355188706
# Train Epoch: 26 [0/3276 (0%)]	Loss: 0.003911
# Train Epoch: 26 [750/3276 (11%)]	Loss: 0.007680
# Train Epoch: 26 [1500/3276 (23%)]	Loss: 0.004525
# Train Epoch: 26 [2250/3276 (34%)]	Loss: 0.004516
# Train Epoch: 26 [3000/3276 (46%)]	Loss: 0.003742
#
# Average Train Epoch Loss:  0.005277893835568128
# Average Train Map Loss:  0.0038463526472372754
# Average Train Count Epoch Loss:  0.14700047249935533
# 	Average Validation Epoch Loss:  0.005470659720766193
# 	Average Validation Map Epoch Loss:  0.0041047773351345
# 	Average Validation Count Epoch Loss:  0.14069301503546097
# Train Epoch: 27 [0/3276 (0%)]	Loss: 0.005348
# Train Epoch: 27 [750/3276 (11%)]	Loss: 0.006161
# Train Epoch: 27 [1500/3276 (23%)]	Loss: 0.004396
# Train Epoch: 27 [2250/3276 (34%)]	Loss: 0.004351
# Train Epoch: 27 [3000/3276 (46%)]	Loss: 0.005677
#
# Average Train Epoch Loss:  0.0051135848984377435
# Average Train Map Loss:  0.003736571067535918
# Average Train Count Epoch Loss:  0.14143795397591918
# 	Average Validation Epoch Loss:  0.005381509483627537
# 	Average Validation Map Epoch Loss:  0.004038551890784327
# 	Average Validation Count Epoch Loss:  0.13833431198316462
# Train Epoch: 28 [0/3276 (0%)]	Loss: 0.004279
# Train Epoch: 28 [750/3276 (11%)]	Loss: 0.005094
# Train Epoch: 28 [1500/3276 (23%)]	Loss: 0.004811
# Train Epoch: 28 [2250/3276 (34%)]	Loss: 0.005083
# Train Epoch: 28 [3000/3276 (46%)]	Loss: 0.005358
#
# Average Train Epoch Loss:  0.0049125625322398525
# Average Train Map Loss:  0.003590342851853228
# Average Train Count Epoch Loss:  0.1358123110887939
# 	Average Validation Epoch Loss:  0.005144178812556407
# 	Average Validation Map Epoch Loss:  0.00389451565056601
# 	Average Validation Count Epoch Loss:  0.1288608325754895
# Train Epoch: 29 [0/3276 (0%)]	Loss: 0.002844
# Train Epoch: 29 [750/3276 (11%)]	Loss: 0.004523
# Train Epoch: 29 [1500/3276 (23%)]	Loss: 0.004320
# Train Epoch: 29 [2250/3276 (34%)]	Loss: 0.003542
# Train Epoch: 29 [3000/3276 (46%)]	Loss: 0.004549
#
# Average Train Epoch Loss:  0.00459346525290275
# Average Train Map Loss:  0.0033840047866403717
# Average Train Count Epoch Loss:  0.12433005131134704
# Train Epoch: 30 [750/3276 (11%)]	Loss: 0.002733
# Train Epoch: 30 [1500/3276 (23%)]	Loss: 0.008623
# Train Epoch: 30 [2250/3276 (34%)]	Loss: 0.006263
# Train Epoch: 30 [3000/3276 (46%)]	Loss: 0.003985
#
# Average Train Epoch Loss:  0.004409765131499397
# Average Train Map Loss:  0.003265660893507982
# Average Train Count Epoch Loss:  0.11767608560111424
# 	Average Validation Epoch Loss:  0.004844990716425373
# 	Average Validation Map Epoch Loss:  0.00359771353439154
# 	Average Validation Count Epoch Loss:  0.1283254345111987
# Train Epoch: 31 [0/3276 (0%)]	Loss: 0.004652
# Train Epoch: 31 [750/3276 (11%)]	Loss: 0.004164
# Train Epoch: 31 [1500/3276 (23%)]	Loss: 0.005077
# Train Epoch: 31 [2250/3276 (34%)]	Loss: 0.004691
# Train Epoch: 31 [3000/3276 (46%)]	Loss: 0.004679
#
# Average Train Epoch Loss:  0.004313719212226399
# Average Train Map Loss:  0.0031830369012183658
# Average Train Count Epoch Loss:  0.1162512675948339
# 	Average Validation Epoch Loss:  0.0049598665688844286
# 	Average Validation Map Epoch Loss:  0.0036612817990210127
# 	Average Validation Count Epoch Loss:  0.13351976433221033
# Train Epoch: 32 [0/3276 (0%)]	Loss: 0.003754
# Train Epoch: 32 [750/3276 (11%)]	Loss: 0.004107
# Train Epoch: 32 [1500/3276 (23%)]	Loss: 0.003729
# Train Epoch: 32 [2250/3276 (34%)]	Loss: 0.004429
# Train Epoch: 32 [3000/3276 (46%)]	Loss: 0.004753
#
# Average Train Epoch Loss:  0.0042966488731778375
# Average Train Map Loss:  0.0031859688195038467
# Average Train Count Epoch Loss:  0.11425397393706183
# 	Average Validation Epoch Loss:  0.0045664376469657705
# 	Average Validation Map Epoch Loss:  0.003325603060040842
# 	Average Validation Count Epoch Loss:  0.12740905845866485
# Train Epoch: 33 [0/3276 (0%)]	Loss: 0.004524
# Train Epoch: 33 [750/3276 (11%)]	Loss: 0.003280
# Train Epoch: 33 [1500/3276 (23%)]	Loss: 0.003212
# Train Epoch: 33 [2250/3276 (34%)]	Loss: 0.003239
# Train Epoch: 33 [3000/3276 (46%)]	Loss: 0.006846
#
# Average Train Epoch Loss:  0.003996823693213125
# Average Train Map Loss:  0.0029720708761857527
# Average Train Count Epoch Loss:  0.10544735116705503
# 	Average Validation Epoch Loss:  0.0045153191518586345
# 	Average Validation Map Epoch Loss:  0.0033129677724312336
# 	Average Validation Count Epoch Loss:  0.12354810689302052
# Train Epoch: 34 [0/3276 (0%)]	Loss: 0.004830
# Train Epoch: 34 [750/3276 (11%)]	Loss: 0.002366
# Train Epoch: 34 [1500/3276 (23%)]	Loss: 0.005883
# Train Epoch: 34 [2250/3276 (34%)]	Loss: 0.003296
# Train Epoch: 34 [3000/3276 (46%)]	Loss: 0.002553
#
# Average Train Epoch Loss:  0.0038648304831423717
# Average Train Map Loss:  0.0028970708627228253
# Average Train Count Epoch Loss:  0.09967303223329592
# 	Average Validation Epoch Loss:  0.004928824053529431
# 	Average Validation Map Epoch Loss:  0.0033673369394177023
# 	Average Validation Count Epoch Loss:  0.15951605360297597
# Train Epoch: 35 [0/3276 (0%)]	Loss: 0.004701
# Train Epoch: 35 [750/3276 (11%)]	Loss: 0.003092
# Train Epoch: 35 [1500/3276 (23%)]	Loss: 0.006873
# Train Epoch: 35 [2250/3276 (34%)]	Loss: 0.003230
# Train Epoch: 35 [3000/3276 (46%)]	Loss: 0.004774
#
# Average Train Epoch Loss:  0.0037329886310636046
# Average Train Map Loss:  0.0028062710420496454
# Average Train Count Epoch Loss:  0.09547803101882543
# 	Average Validation Epoch Loss:  0.004585298024775351
# 	Average Validation Map Epoch Loss:  0.0032936213127173044
# 	Average Validation Count Epoch Loss:  0.13246127700104432
# Train Epoch: 36 [0/3276 (0%)]	Loss: 0.002701
# Train Epoch: 36 [750/3276 (11%)]	Loss: 0.004399
# Train Epoch: 36 [1500/3276 (23%)]	Loss: 0.004425
# Train Epoch: 36 [2250/3276 (34%)]	Loss: 0.003947
# Train Epoch: 36 [3000/3276 (46%)]	Loss: 0.002395
#
# Average Train Epoch Loss:  0.0036281190996513314
# Average Train Map Loss:  0.0027654092175754203
# Average Train Count Epoch Loss:  0.08903639715964391
# 	Average Validation Epoch Loss:  0.004580209031701088
# 	Average Validation Map Epoch Loss:  0.003087760805261924
# 	Average Validation Count Epoch Loss:  0.15233258223708937
# Train Epoch: 37 [0/3276 (0%)]	Loss: 0.004773
# Train Epoch: 37 [750/3276 (11%)]	Loss: 0.004197
# Train Epoch: 37 [1500/3276 (23%)]	Loss: 0.005325
# Train Epoch: 37 [2250/3276 (34%)]	Loss: 0.002433
# Train Epoch: 37 [3000/3276 (46%)]	Loss: 0.002294
#
# Average Train Epoch Loss:  0.0035126307595427656
# Average Train Map Loss:  0.0027103138673991033
# Average Train Count Epoch Loss:  0.0829420022360266
# 	Average Validation Epoch Loss:  0.004530422238852172
# 	Average Validation Map Epoch Loss:  0.0032191511435324654
# 	Average Validation Count Epoch Loss:  0.13434625789523125
# Train Epoch: 38 [0/3276 (0%)]	Loss: 0.002824
# Train Epoch: 38 [750/3276 (11%)]	Loss: 0.002592
# Train Epoch: 38 [1500/3276 (23%)]	Loss: 0.002055
# Train Epoch: 38 [2250/3276 (34%)]	Loss: 0.002938
# Train Epoch: 38 [3000/3276 (46%)]	Loss: 0.004986
#
# Average Train Epoch Loss:  0.0033410439798268214
# Average Train Map Loss:  0.0025800754737159977
# Average Train Count Epoch Loss:  0.0786769254532851
# 	Average Validation Epoch Loss:  0.004737824365934905
# 	Average Validation Map Epoch Loss:  0.0032302709501784515
# 	Average Validation Count Epoch Loss:  0.153985614724019
# Train Epoch: 39 [0/3276 (0%)]	Loss: 0.001574
# Train Epoch: 39 [750/3276 (11%)]	Loss: 0.001368
# Train Epoch: 39 [1500/3276 (23%)]	Loss: 0.002364
# Train Epoch: 39 [2250/3276 (34%)]	Loss: 0.003377
# Train Epoch: 39 [3000/3276 (46%)]	Loss: 0.002392
#
# Average Train Epoch Loss:  0.003194895503855391
# Average Train Map Loss:  0.002510202293481984
# Average Train Count Epoch Loss:  0.07097952327261504
# 	Average Validation Epoch Loss:  0.004280512317028993
# 	Average Validation Map Epoch Loss:  0.0030588284682701618
# 	Average Validation Count Epoch Loss:  0.125227211152806
# Train Epoch: 40 [0/3276 (0%)]	Loss: 0.002250
# Train Epoch: 40 [750/3276 (11%)]	Loss: 0.002382
# Train Epoch: 40 [1500/3276 (23%)]	Loss: 0.001953
# Train Epoch: 40 [2250/3276 (34%)]	Loss: 0.004403
# Train Epoch: 40 [3000/3276 (46%)]	Loss: 0.001735
#
# Average Train Epoch Loss:  0.003167509129504805
# Average Train Map Loss:  0.0024755468257685875
# Average Train Count Epoch Loss:  0.07167177698383592
# 	Average Validation Epoch Loss:  0.004578638226067757
# 	Average Validation Map Epoch Loss:  0.003101831456125878
# 	Average Validation Count Epoch Loss:  0.1507825069129467
# Train Epoch: 41 [0/3276 (0%)]	Loss: 0.003148
# Train Epoch: 41 [750/3276 (11%)]	Loss: 0.003033
# Train Epoch: 41 [1500/3276 (23%)]	Loss: 0.001602
# Train Epoch: 41 [2250/3276 (34%)]	Loss: 0.002093
# Train Epoch: 41 [3000/3276 (46%)]	Loss: 0.004343
#
# Average Train Epoch Loss:  0.002957270212777673
# Average Train Map Loss:  0.002362083275026331
# Average Train Count Epoch Loss:  0.06188077585491007
# 	Average Validation Epoch Loss:  0.004204677938319305
# 	Average Validation Map Epoch Loss:  0.0028265171328230817
# 	Average Validation Count Epoch Loss:  0.1406425960800227
# Train Epoch: 42 [0/3276 (0%)]	Loss: 0.003349
# Train Epoch: 42 [750/3276 (11%)]	Loss: 0.002621
# Train Epoch: 42 [1500/3276 (23%)]	Loss: 0.002285
# Train Epoch: 42 [2250/3276 (34%)]	Loss: 0.002490
# Train Epoch: 42 [3000/3276 (46%)]	Loss: 0.003661
#
# Average Train Epoch Loss:  0.002911312937243208
# Average Train Map Loss:  0.0023138037971518594
# Average Train Count Epoch Loss:  0.062064715971549354
# 	Average Validation Epoch Loss:  0.003998753655811443
# 	Average Validation Map Epoch Loss:  0.0028127002913285702
# 	Average Validation Count Epoch Loss:  0.12141803542480749
# Train Epoch: 43 [0/3276 (0%)]	Loss: 0.006452
# Train Epoch: 43 [750/3276 (11%)]	Loss: 0.003938
# Train Epoch: 43 [1500/3276 (23%)]	Loss: 0.001337
# Train Epoch: 43 [2250/3276 (34%)]	Loss: 0.001728
# Train Epoch: 43 [3000/3276 (46%)]	Loss: 0.001186
#
# Average Train Epoch Loss:  0.002893257988234089
# Average Train Map Loss:  0.002330697520336213
# Average Train Count Epoch Loss:  0.058586743149957425
# 	Average Validation Epoch Loss:  0.0039277711527093365
# 	Average Validation Map Epoch Loss:  0.002836134818875614
# 	Average Validation Count Epoch Loss:  0.11199976262800834
# Train Epoch: 44 [0/3276 (0%)]	Loss: 0.002104
# Train Epoch: 44 [750/3276 (11%)]	Loss: 0.001878
# Train Epoch: 44 [1500/3276 (23%)]	Loss: 0.002199
# Train Epoch: 44 [2250/3276 (34%)]	Loss: 0.000901
# Train Epoch: 44 [3000/3276 (46%)]	Loss: 0.002835
#
# Average Train Epoch Loss:  0.0027071593957102634
# Average Train Map Loss:  0.002205981063118553
# Average Train Count Epoch Loss:  0.052323814349665765
# 	Average Validation Epoch Loss:  0.0042907392592443265
# 	Average Validation Map Epoch Loss:  0.0028298990321619544
# 	Average Validation Count Epoch Loss:  0.14891392584232724
# Train Epoch: 45 [0/3276 (0%)]	Loss: 0.002684
# Train Epoch: 45 [750/3276 (11%)]	Loss: 0.002067
# Train Epoch: 45 [1500/3276 (23%)]	Loss: 0.005155
# Train Epoch: 45 [2250/3276 (34%)]	Loss: 0.007200
# Train Epoch: 45 [3000/3276 (46%)]	Loss: 0.003220
#
# Average Train Epoch Loss:  0.002587213761175315
# Average Train Map Loss:  0.002157879510647766
# Average Train Count Epoch Loss:  0.04509130486002252
# 	Average Validation Epoch Loss:  0.004324830287848325
# 	Average Validation Map Epoch Loss:  0.002958879751317641
# 	Average Validation Count Epoch Loss:  0.1395539346644107
# Train Epoch: 46 [0/3276 (0%)]	Loss: 0.001858
# Train Epoch: 46 [750/3276 (11%)]	Loss: 0.003512
# Train Epoch: 46 [1500/3276 (23%)]	Loss: 0.001200
# Train Epoch: 46 [2250/3276 (34%)]	Loss: 0.001500
# Train Epoch: 46 [3000/3276 (46%)]	Loss: 0.002205
#
# Average Train Epoch Loss:  0.002539694499007541
# Average Train Map Loss:  0.0020772162516554606
# Average Train Count Epoch Loss:  0.04832503911252367
# 	Average Validation Epoch Loss:  0.0043325567179742985
# 	Average Validation Map Epoch Loss:  0.0028780738083536133
# 	Average Validation Count Epoch Loss:  0.1483263719607802
# Train Epoch: 47 [0/3276 (0%)]	Loss: 0.003214
# Train Epoch: 47 [750/3276 (11%)]	Loss: 0.003205
# Train Epoch: 47 [1500/3276 (23%)]	Loss: 0.004268
# Train Epoch: 47 [2250/3276 (34%)]	Loss: 0.002801
# Train Epoch: 47 [3000/3276 (46%)]	Loss: 0.003485
#
# Average Train Epoch Loss:  0.002638133379341567
# Average Train Map Loss:  0.0021402502254918897
# Average Train Count Epoch Loss:  0.0519285646424582
# 	Average Validation Epoch Loss:  0.0047657518127166175
# 	Average Validation Map Epoch Loss:  0.002800899263307014
# 	Average Validation Count Epoch Loss:  0.19928616329151042
# Train Epoch: 48 [0/3276 (0%)]	Loss: 0.001663
# Train Epoch: 48 [750/3276 (11%)]	Loss: 0.001368
# Train Epoch: 48 [1500/3276 (23%)]	Loss: 0.001594
# Train Epoch: 48 [2250/3276 (34%)]	Loss: 0.002328
# Train Epoch: 48 [3000/3276 (46%)]	Loss: 0.001933
#
# Average Train Epoch Loss:  0.002430600885484691
# Average Train Map Loss:  0.0019985628702367344
# Average Train Count Epoch Loss:  0.04520236271471806
# 	Average Validation Epoch Loss:  0.003962034647188643
# 	Average Validation Map Epoch Loss:  0.0027595851296449408
# 	Average Validation Count Epoch Loss:  0.1230045367470559
# Train Epoch: 49 [0/3276 (0%)]	Loss: 0.001238
# Train Epoch: 49 [750/3276 (11%)]	Loss: 0.002005
# Train Epoch: 49 [1500/3276 (23%)]	Loss: 0.001354
# Train Epoch: 49 [2250/3276 (34%)]	Loss: 0.002519
# Train Epoch: 49 [3000/3276 (46%)]	Loss: 0.001708
#
# Average Train Epoch Loss:  0.0023111489866690107
# Average Train Map Loss:  0.0019150702503390746
# Average Train Count Epoch Loss:  0.04152294265990864
# 	Average Validation Epoch Loss:  0.0044845572042771994
# 	Average Validation Map Epoch Loss:  0.002839632797986269
# 	Average Validation Count Epoch Loss:  0.16733207750846357
# Train Epoch: 50 [0/3276 (0%)]	Loss: 0.001754
# Train Epoch: 50 [750/3276 (11%)]	Loss: 0.001470
# Train Epoch: 50 [1500/3276 (23%)]	Loss: 0.001070
# Train Epoch: 50 [2250/3276 (34%)]	Loss: 0.003263
# Train Epoch: 50 [3000/3276 (46%)]	Loss: 0.001104
#
# Average Train Epoch Loss:  0.0022998223908896214
# Average Train Map Loss:  0.0019266342573595067
# Average Train Count Epoch Loss:  0.0392454466995141
# 	Average Validation Epoch Loss:  0.004156631759970504
# 	Average Validation Map Epoch Loss:  0.0027639410588616397
# 	Average Validation Count Epoch Loss:  0.14203301422736225
# Train Epoch: 51 [0/3276 (0%)]	Loss: 0.003000
# Train Epoch: 51 [750/3276 (11%)]	Loss: 0.002142
# Train Epoch: 51 [1500/3276 (23%)]	Loss: 0.001628
# Train Epoch: 51 [2250/3276 (34%)]	Loss: 0.001777
# Train Epoch: 51 [3000/3276 (46%)]	Loss: 0.001341
#
# Average Train Epoch Loss:  0.002252882532296983
# Average Train Map Loss:  0.0018523364459679006
# Average Train Count Epoch Loss:  0.04190694466318306
# 	Average Validation Epoch Loss:  0.004391595488414168
# 	Average Validation Map Epoch Loss:  0.0027361678315655272
# 	Average Validation Count Epoch Loss:  0.16827893607756672
# Train Epoch: 52 [0/3276 (0%)]	Loss: 0.001704
# Train Epoch: 52 [750/3276 (11%)]	Loss: 0.002088
# Train Epoch: 52 [1500/3276 (23%)]	Loss: 0.001256
# Train Epoch: 52 [2250/3276 (34%)]	Loss: 0.001477
# Train Epoch: 52 [3000/3276 (46%)]	Loss: 0.003755
#
# Average Train Epoch Loss:  0.002154790469685561
# Average Train Map Loss:  0.0018075245855690817
# Average Train Count Epoch Loss:  0.036534111821369085
# 	Average Validation Epoch Loss:  0.004233893678140114
# 	Average Validation Map Epoch Loss:  0.0026547491399790436
# 	Average Validation Count Epoch Loss:  0.1605692001826623
# Train Epoch: 53 [0/3276 (0%)]	Loss: 0.001283
# Train Epoch: 53 [750/3276 (11%)]	Loss: 0.000933
# Train Epoch: 53 [1500/3276 (23%)]	Loss: 0.000960
# Train Epoch: 53 [2250/3276 (34%)]	Loss: 0.001176
# Train Epoch: 53 [3000/3276 (46%)]	Loss: 0.002040
#
# Average Train Epoch Loss:  0.002104201629708976
# Average Train Map Loss:  0.0017647740003742176
# Average Train Count Epoch Loss:  0.03570753533699333
# 	Average Validation Epoch Loss:  0.004263609921669259
# 	Average Validation Map Epoch Loss:  0.0027505034402779795
# 	Average Validation Count Epoch Loss:  0.15406115396934397
# Train Epoch: 54 [0/3276 (0%)]	Loss: 0.004757
# Train Epoch: 54 [750/3276 (11%)]	Loss: 0.001967
# Train Epoch: 54 [1500/3276 (23%)]	Loss: 0.000908
# Train Epoch: 54 [2250/3276 (34%)]	Loss: 0.000965
# Train Epoch: 54 [3000/3276 (46%)]	Loss: 0.000881
#
# Average Train Epoch Loss:  0.002110378954402218
# Average Train Map Loss:  0.0017852302831778363
# Average Train Count Epoch Loss:  0.034300097521632635
# 	Average Validation Epoch Loss:  0.004604985553990392
# 	Average Validation Map Epoch Loss:  0.003019613049486104
# 	Average Validation Count Epoch Loss:  0.16155687106006286
# Train Epoch: 55 [0/3276 (0%)]	Loss: 0.001257
# Train Epoch: 55 [750/3276 (11%)]	Loss: 0.000971
# Train Epoch: 55 [1500/3276 (23%)]	Loss: 0.002005
# Train Epoch: 55 [2250/3276 (34%)]	Loss: 0.003401
# Train Epoch: 55 [3000/3276 (46%)]	Loss: 0.002652
#
# Average Train Epoch Loss:  0.001954175494388001
# Average Train Map Loss:  0.0016881591665928494
# Average Train Count Epoch Loss:  0.028289791315657908
# 	Average Validation Epoch Loss:  0.004234008984092404
# 	Average Validation Map Epoch Loss:  0.002873332636869129
# 	Average Validation Count Epoch Loss:  0.13894096887944377
# Train Epoch: 56 [0/3276 (0%)]	Loss: 0.001909
# Train Epoch: 56 [750/3276 (11%)]	Loss: 0.006339
# Train Epoch: 56 [1500/3276 (23%)]	Loss: 0.002457
# Train Epoch: 56 [2250/3276 (34%)]	Loss: 0.001283
# Train Epoch: 56 [3000/3276 (46%)]	Loss: 0.002351
#
# Average Train Epoch Loss:  0.0019343891080052136
# Average Train Map Loss:  0.0016701033423425094
# Average Train Count Epoch Loss:  0.028098678881872327
# 	Average Validation Epoch Loss:  0.004380212035304045
# 	Average Validation Map Epoch Loss:  0.002934787730576799
# 	Average Validation Count Epoch Loss:  0.1474772106636973
# Train Epoch: 57 [0/3276 (0%)]	Loss: 0.001172
# Train Epoch: 57 [750/3276 (11%)]	Loss: 0.001729
# Train Epoch: 57 [1500/3276 (23%)]	Loss: 0.001124
# Train Epoch: 57 [2250/3276 (34%)]	Loss: 0.002109
# Train Epoch: 57 [3000/3276 (46%)]	Loss: 0.002420
#
# Average Train Epoch Loss:  0.0018847147545024549
# Average Train Map Loss:  0.0016075795708802533
# Average Train Count Epoch Loss:  0.02932109671100532
# 	Average Validation Epoch Loss:  0.004331576994017643
# 	Average Validation Map Epoch Loss:  0.002772487686289584
# 	Average Validation Count Epoch Loss:  0.15868141293963967
# Train Epoch: 58 [0/3276 (0%)]	Loss: 0.003021
# Train Epoch: 58 [750/3276 (11%)]	Loss: 0.003637
# Train Epoch: 58 [1500/3276 (23%)]	Loss: 0.002697
# Train Epoch: 58 [2250/3276 (34%)]	Loss: 0.000883
# Train Epoch: 58 [3000/3276 (46%)]	Loss: 0.004167
#
# Average Train Epoch Loss:  0.0018210041971417935
# Average Train Map Loss:  0.0015731800293611558
# Average Train Count Epoch Loss:  0.026355595939227094
# 	Average Validation Epoch Loss:  0.004111197804484297
# 	Average Validation Map Epoch Loss:  0.0025621054125675824
# 	Average Validation Count Epoch Loss:  0.1574713416835841
# Train Epoch: 59 [0/3276 (0%)]	Loss: 0.001283
# Train Epoch: 59 [750/3276 (11%)]	Loss: 0.000796
# Train Epoch: 59 [1500/3276 (23%)]	Loss: 0.002526
# Train Epoch: 59 [2250/3276 (34%)]	Loss: 0.001384
# Train Epoch: 59 [3000/3276 (46%)]	Loss: 0.001706
#
# Average Train Epoch Loss:  0.0018592616899330255
# Average Train Map Loss:  0.0015829059479547639
# Average Train Count Epoch Loss:  0.02921847964224478
# 	Average Validation Epoch Loss:  0.004658740815049147
# 	Average Validation Map Epoch Loss:  0.003026540733545142
# 	Average Validation Count Epoch Loss:  0.1662465430357877
# Train Epoch: 60 [0/3276 (0%)]	Loss: 0.002182
# Train Epoch: 60 [750/3276 (11%)]	Loss: 0.000927
# Train Epoch: 60 [1500/3276 (23%)]	Loss: 0.001215
# Train Epoch: 60 [2250/3276 (34%)]	Loss: 0.002189
# Train Epoch: 60 [3000/3276 (46%)]	Loss: 0.000581
#
# Average Train Epoch Loss:  0.001760684831926948
# Average Train Map Loss:  0.0015273593677384311
# Average Train Count Epoch Loss:  0.024859904354123493
# 	Average Validation Epoch Loss:  0.004345047369818477
# 	Average Validation Map Epoch Loss:  0.00284504667198395
# 	Average Validation Count Epoch Loss:  0.152845116222606
# Train Epoch: 61 [0/3276 (0%)]	Loss: 0.001106
# Train Epoch: 61 [750/3276 (11%)]	Loss: 0.001006
# Train Epoch: 61 [2250/3276 (34%)]	Loss: 0.001489
# Train Epoch: 61 [3000/3276 (46%)]	Loss: 0.001111
#
# Average Train Epoch Loss:  0.0016475217927196255
# Average Train Map Loss:  0.0014485373674970562
# Average Train Count Epoch Loss:  0.021346978568386916
# 	Average Validation Epoch Loss:  0.0047026216326391
# 	Average Validation Map Epoch Loss:  0.0028947896858239
# 	Average Validation Count Epoch Loss:  0.18367799327653997
# Train Epoch: 62 [0/3276 (0%)]	Loss: 0.001099
# Train Epoch: 62 [750/3276 (11%)]	Loss: 0.000826
# Train Epoch: 62 [1500/3276 (23%)]	Loss: 0.004026
# Train Epoch: 62 [2250/3276 (34%)]	Loss: 0.003261
# Train Epoch: 62 [3000/3276 (46%)]	Loss: 0.001345
#
# Average Train Epoch Loss:  0.0021218062122246107
# Average Train Map Loss:  0.0017518161218740965
# Average Train Count Epoch Loss:  0.03875082479917431
# 	Average Validation Epoch Loss:  0.0041375517406884365
# 	Average Validation Map Epoch Loss:  0.0026578459929784432
# 	Average Validation Count Epoch Loss:  0.15062842342783422
# Train Epoch: 63 [0/3276 (0%)]	Loss: 0.001730
# Train Epoch: 63 [750/3276 (11%)]	Loss: 0.001935
# Train Epoch: 63 [1500/3276 (23%)]	Loss: 0.001609
# Train Epoch: 63 [2250/3276 (34%)]	Loss: 0.000854
# Train Epoch: 63 [3000/3276 (46%)]	Loss: 0.004730
#
# Average Train Epoch Loss:  0.0017773687231384184
# Average Train Map Loss:  0.0015520399024914185
# Average Train Count Epoch Loss:  0.024084921123579007
# 	Average Validation Epoch Loss:  0.004293088650550036
# 	Average Validation Map Epoch Loss:  0.0026708515018553417
# 	Average Validation Count Epoch Loss:  0.16489456856951995
# Train Epoch: 64 [0/3276 (0%)]	Loss: 0.001088
# Train Epoch: 64 [750/3276 (11%)]	Loss: 0.001862
# Train Epoch: 64 [1500/3276 (23%)]	Loss: 0.002168
# Train Epoch: 64 [2250/3276 (34%)]	Loss: 0.000672
# Train Epoch: 64 [3000/3276 (46%)]	Loss: 0.001225
#
# Average Train Epoch Loss:  0.0016633147045812615
# Average Train Map Loss:  0.0014685887341561927
# Average Train Count Epoch Loss:  0.020941184602941483
# 	Average Validation Epoch Loss:  0.004134720889851451
# 	Average Validation Map Epoch Loss:  0.00264063777456827
# 	Average Validation Count Epoch Loss:  0.15204894707045136
# Train Epoch: 65 [0/3276 (0%)]	Loss: 0.002068
# Train Epoch: 65 [750/3276 (11%)]	Loss: 0.001017
# Train Epoch: 65 [1500/3276 (23%)]	Loss: 0.000883
# Train Epoch: 65 [2250/3276 (34%)]	Loss: 0.000978
# Train Epoch: 65 [3000/3276 (46%)]	Loss: 0.000569
#
# Average Train Epoch Loss:  0.001510649723889621
# Average Train Map Loss:  0.0013675117206315352
# Average Train Count Epoch Loss:  0.015681310770522854
# 	Average Validation Epoch Loss:  0.004478714106987943
# 	Average Validation Map Epoch Loss:  0.0026670004008337855
# 	Average Validation Count Epoch Loss:  0.1838383700917749
# Train Epoch: 66 [0/3276 (0%)]	Loss: 0.001604
# Train Epoch: 66 [750/3276 (11%)]	Loss: 0.001054
# Train Epoch: 66 [1500/3276 (23%)]	Loss: 0.000831
# Train Epoch: 66 [2250/3276 (34%)]	Loss: 0.002503
# Train Epoch: 66 [3000/3276 (46%)]	Loss: 0.001280
#
# Average Train Epoch Loss:  0.0014745496876843987
# Average Train Map Loss:  0.001336239298782205
# Average Train Count Epoch Loss:  0.01516727723827645
# 	Average Validation Epoch Loss:  0.004295255307464258
# 	Average Validation Map Epoch Loss:  0.0027271026629023254
# 	Average Validation Count Epoch Loss:  0.15954236998496688
# Train Epoch: 67 [0/3276 (0%)]	Loss: 0.000481
# Train Epoch: 67 [1500/3276 (23%)]	Loss: 0.000790
# Train Epoch: 67 [2250/3276 (34%)]	Loss: 0.001359
# Train Epoch: 67 [3000/3276 (46%)]	Loss: 0.001488
#
# Average Train Epoch Loss:  0.001448099060620917
# Average Train Map Loss:  0.001306286166192428
# Average Train Count Epoch Loss:  0.015487573968595294
# 	Average Validation Epoch Loss:  0.004035669735030216
# 	Average Validation Map Epoch Loss:  0.0026618245550814796
# 	Average Validation Count Epoch Loss:  0.14004633937250166
# Train Epoch: 68 [0/3276 (0%)]	Loss: 0.001474
# Train Epoch: 68 [750/3276 (11%)]	Loss: 0.001764
# Train Epoch: 68 [1500/3276 (23%)]	Loss: 0.001562
# Train Epoch: 68 [2250/3276 (34%)]	Loss: 0.001078
# Train Epoch: 68 [3000/3276 (46%)]	Loss: 0.001139
#
# Average Train Epoch Loss:  0.0015642955696176244
# Average Train Map Loss:  0.0013679471868940855
# Average Train Count Epoch Loss:  0.021002784690322126
# 	Average Validation Epoch Loss:  0.004520920783226543
# 	Average Validation Map Epoch Loss:  0.002842835119843264
# 	Average Validation Count Epoch Loss:  0.1706514092271819
# Train Epoch: 69 [0/3276 (0%)]	Loss: 0.001456
# Train Epoch: 69 [750/3276 (11%)]	Loss: 0.001376
# Train Epoch: 69 [1500/3276 (23%)]	Loss: 0.001488
# Train Epoch: 69 [2250/3276 (34%)]	Loss: 0.001584
# Train Epoch: 69 [3000/3276 (46%)]	Loss: 0.001556
#
# Average Train Epoch Loss:  0.001494455068068128
# Average Train Map Loss:  0.0013444405282979413
# Average Train Count Epoch Loss:  0.016345893439505096
# 	Average Validation Epoch Loss:  0.00413489544435459
# 	Average Validation Map Epoch Loss:  0.002663955544395482
# 	Average Validation Count Epoch Loss:  0.14975794163696907
# Train Epoch: 70 [0/3276 (0%)]	Loss: 0.001181
# Train Epoch: 70 [750/3276 (11%)]	Loss: 0.002118
# Train Epoch: 70 [1500/3276 (23%)]	Loss: 0.001228
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-151-c210533f9059>", line 3, in <module>
#     train()
#   File "<ipython-input-148-c4591e184811>", line 15, in train
#     for i, (sample, bbox_bins, road_maps, bbs, target_count, _) in enumerate(train_loader):
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 345, in __next__
#     data = self._next_data()
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 841, in _next_data
#     idx, data = self._get_data()
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 808, in _get_data
#     success, data = self._try_get_data()
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 761, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/queues.py", line 113, in get
#     return _ForkingPickler.loads(res)
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 294, in rebuild_storage_fd
#     fd = df.detach()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/connection.py", line 494, in Client
#     deliver_challenge(c, authkey)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/connection.py", line 720, in deliver_challenge
#     connection.send_bytes(CHALLENGE + message)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 1442, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 179, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/home/vr1059/py3.6.3/lib/python3.6/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/home/vr1059/py3.6.3/lib/python3.6/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/home/vr1059/py3.6.3/lib/python3.6/tokenize.py", line 454, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/home/vr1059/py3.6.3/lib/python3.6/tokenize.py", line 423, in detect_encoding
#     first = read_or_stop()
#   File "/home/vr1059/py3.6.3/lib/python3.6/tokenize.py", line 381, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Process Process-1429:
# Process Process-1430:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt

# %%
# 0.00259 best val map loss. 
# I'm getting 0.3/0.4 iou_threshold scores like every time there's a car now. 
# I feel like if I do 0.9, 0.1 split, then we can focus more on map loss. 

# Next thing to do is 0.95, 0.05 split for map loss. 
# Got 0.2149 best val map loss. 

# Trying 0.99, 0.01 split now. 
# And also added an extra 100-MLP layer. 
# 0.00213 best val map loss. 

# Next thing to do is lr flips. 

# I might have to decrease hue, or not do it at all. 
# It might be messing up the model. All the bright colors and shit. 

# 0.00256 best val map loss
