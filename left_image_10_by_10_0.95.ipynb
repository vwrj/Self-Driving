# %%
import os
import random
import math
import kornia
import numpy as np
import pandas as pd
import pdb
from collections import OrderedDict
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import collections  as mc
matplotlib.rcParams['figure.figsize'] = [6, 6]
matplotlib.rcParams['figure.dpi'] = 200

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms

from data_helper import UnlabeledDataset, LabeledDataset
from helper import draw_box

# random.seed(0)
# np.random.seed(0)
# torch.manual_seed(0);

# All the images are saved in image_folder
# All the labels are saved in the annotation_csv file
image_folder = '/scratch/brs426/data'
annotation_csv = '/scratch/brs426/data/annotation.csv'

# You shouldn't change the unlabeled_scene_index
# The first 106 scenes are unlabeled
unlabeled_scene_index = np.arange(106)
# The scenes from 106 - 133 are labeled
# You should devide the labeled_scene_index into two subsets (training and validation)
train_labeled_scene_index = np.arange(106, 132)
val_labeled_scene_index = np.arange(132, 134)
test_labeled_scene_index = np.arange(132, 134)

from helper import compute_ats_bounding_boxes, compute_ts_road_map

from math import acos
from math import sqrt
from math import pi

# %%
def length(v):
    return sqrt(v[0]**2+v[1]**2)

def dot_product(v,w):
    return v[0]*w[0]+v[1]*w[1]

def determinant(v,w):
    return v[0]*w[1]-v[1]*w[0]

def inner_angle(v,w):
    cosx=dot_product(v,w)/(length(v)*length(w))
    rad=acos(cosx) # in radians
    return rad*180/pi # returns degrees

def angle_clockwise(A, B):
    inner=inner_angle(A,B)
    det = determinant(A,B)
    if det<0: #this is a property of the det. If the det < 0 then B is clockwise of A
        return inner
    else: # if the det > 0 then A is immediately clockwise of B
        return 360-inner

# %%
def within_angles(xs, ys, angle1 = 272, angle2 = 330):
    '''
    xs and ys must be corresponding coordinates in matplotlib-space (y-axis 0 starts from the top).
    '''
    
    # Matplotlib y-axis -- 0 starts from the top, so we need to adjust. 
    v0 = np.array([xs[0] - 400, 800 - ys[0] - 400])
    v1 = np.array([xs[1] - 400, 800 - ys[1] - 400])
    v2 = np.array([xs[2] - 400, 800 - ys[2] - 400])
    v3 = np.array([xs[3] - 400, 800 - ys[3] - 400])
    v_ref = np.array([2, 0])
    
    condition = (angle_clockwise(v_ref, v0) >= angle1 and angle_clockwise(v_ref, v0) <= angle2) or \
                (angle_clockwise(v_ref, v1) >= angle1 and angle_clockwise(v_ref, v1) <= angle2) or \
                (angle_clockwise(v_ref, v2) >= angle1 and angle_clockwise(v_ref, v2) <= angle2) or \
                (angle_clockwise(v_ref, v3) >= angle1 and angle_clockwise(v_ref, v3) <= angle2)
    return condition

# %%
VERT_BLOCK_SIZE = 10
HORIZ_BLOCK_SIZE = 10
BLOCK_AREA = VERT_BLOCK_SIZE * HORIZ_BLOCK_SIZE

# %%
def blur(img):
    img = img.unsqueeze(0)
    blurred = kornia.filters.gaussian_blur2d(img, kernel_size=(5, 5), sigma=(9.5, 9.5))
    return blurred.squeeze(0)

# %%
def collate_fn(batch):
    left_images = []
    target = []
    road_maps = []
    bbox_maps = []
    bbox_bins = []
    bbs = []
    target_counts = []
    for x in batch:
        
        # Get road_image and cast it to float
        road_image = torch.as_tensor(x[2]).float()
        road_maps.append(road_image)
        
        # Collect six images for this sample. 
        # TODO: Try cutting off the top 100 pixels (that can lead to overfitting)
        image = torch.Tensor(x[0][0])[:, 130:, :]
        left_images.append(image)
        
        # target
        bb_tens = x[1]['bounding_box']
        current_bbs = []
        bbox_map = torch.zeros((800, 800))
        counts = np.zeros(8)
        count = 0
        
        # Create the bounding box map. 
        for i, corners in enumerate(bb_tens):
            
            # Grab the current bounding box. 
            current_bbs.append(corners)
            
            # Get its four bird's-eye view coordinates. 
            point_squence = torch.stack([corners[:, 0], corners[:, 1], corners[:, 3], corners[:, 2]])
            xs = point_squence.T[0] * 10 + 400
            ys = -point_squence.T[1] * 10 + 400
            
            # xs is horizontal, ys is vertical through. 
            # But we're doing things row, column way. 
            
            # Only get the bounding boxes that are close-by. On the same road. 
            # We want to see if the model can fucking predict cars that are close by. 
            
            center_x, center_y = torch.mean(xs).item(), torch.mean(ys).item()
            if within_angles(xs, ys) and center_y > 300 and center_y < 525:
            
                # Grab the top-left coordinates. 
                r, c = int(torch.min(ys).item()), int(torch.min(xs).item())
                r_len, c_len = int(torch.max(ys).item()) - r, int(torch.max(xs).item()) - c

                # Fill in the bbox. 
                bbox_map[r:r+r_len, c:c+c_len] = 1.0

                count += 1
            
        # Convert the bounding box map into classes (5px by 5px bins)
        bbox_grid = []
        for x_ in range(0, 800, VERT_BLOCK_SIZE):
            for y in range(0, 800, HORIZ_BLOCK_SIZE):
                block = bbox_map[x_:x_+VERT_BLOCK_SIZE, y:y+HORIZ_BLOCK_SIZE]
                score = torch.sum(block).item()
                # If more than have the pixels are 1, classify as bbox car
                if score > 0.5 * (BLOCK_AREA):
                    bbox_grid.append(1.0)
                else:
                    bbox_grid.append(0.0)
                    
        bbox_bins.append(torch.Tensor(bbox_grid))
              
        counts[count] = 1

        # Label Smoothing #
#         if count > 15 and count < 88:
#             counts[count+1] = 0.2
#             counts[count-1] = 0.2
            
        target_counts.append(torch.Tensor(counts))
        
        bbox_maps.append(bbox_map)

        bbs.append(current_bbs)
                
    boom = torch.stack(left_images), torch.stack(bbox_bins), torch.stack(road_maps), bbs, torch.stack(target_counts), torch.stack(bbox_maps) 
    return boom

# %%
val_transform = transforms.ToTensor()

train_transform = transforms.Compose([
    transforms.ColorJitter(brightness = 0.5, contrast = 0.5, saturation = 0.4, hue = (-0.5, 0.5)),
    transforms.RandomApply([
        transforms.Grayscale(3),
#         transforms.RandomAffine(1),
    ]),
    transforms.ToTensor(),
    transforms.RandomApply([
        transforms.Lambda(lambda img: blur(img)),
    ])
])

labeled_trainset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=train_labeled_scene_index,
                                  transform=train_transform,
                                  extra_info=True
                                 )

labeled_valset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=val_labeled_scene_index,
                                  transform=val_transform,
                                  extra_info=True
                                 )

# %% [markdown]
# #### Testing

# %%
train_loader = torch.utils.data.DataLoader(labeled_trainset, batch_size=16, shuffle=True, collate_fn=collate_fn)

# %%
# Compute threat scores
def reconstruct_from_bins(bins, threshold):
    print(bins.shape)
    road_map = torch.zeros((800, 800))
    idx = 0
    for x in range(0, 800, VERT_BLOCK_SIZE):
        for y in range(0, 800, HORIZ_BLOCK_SIZE):
            road_map[x:x+VERT_BLOCK_SIZE, y:y+HORIZ_BLOCK_SIZE] = bins[idx]
            idx += 1
    return road_map > threshold

# %%
sample, bbox_bins, road_maps, bbs, counts, bbox_maps  = iter(train_loader).next()

# %%
idx = -1

# %%
idx += 1

# %%
print(torch.argmax(counts[idx]))
matplotlib.rcParams['figure.figsize'] = [5,5]
plt.imshow(sample[idx].numpy().transpose(1, 2, 0))
plt.axis('off');
# Out:
# tensor(1)

# %%
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [3,3]
fig, ax = plt.subplots()
ax.imshow(road_maps[idx], cmap ='binary');
ax.plot(400, 400, 'x', color="red")
for bb in bbs[idx]:
    draw_box(ax, bb, 'orange')

# %%
threshold = 0.5
road_map = reconstruct_from_bins(bbox_bins[idx], threshold)
fig, ax = plt.subplots()
ax.imshow(road_map, cmap ='binary');
ax.plot(400, 400, 'x', color="red")
# Out:
# torch.Size([6400])

# %% [markdown]
# ### Model

# %%
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        
        self.encoder = torchvision.models.resnet18()
        self.encoder.fc = nn.Identity()
        self.concat_dim = 100
        self.dropout = nn.Dropout(p = 0.2)
        self.bn = nn.BatchNorm1d(self.concat_dim)
        
        self.compress = nn.Sequential(OrderedDict([
            ('linear0', nn.Linear(512, 100)),
            ('relu', nn.ReLU()),
            ('linear1', nn.Linear(100, 100)),
            ('relu1', nn.ReLU()),
        ]))
        
        self.vehicle_map = nn.Sequential(OrderedDict([
            ('linear1_vehicle', nn.Linear(self.concat_dim, 6400)),
        ]))
        
        self.counts = nn.Sequential(OrderedDict([
            ('count1', nn.Linear(self.concat_dim, 8))
        ]))
        
    def forward(self, x):
        
        batch_size = x.shape[0]
        channels = x.shape[1]
        height = x.shape[2]
        width = x.shape[3]
        # Reshape here
        x = x.view(-1, channels, height, width)
        x = self.encoder(x)
        x = self.compress(x)
        x = x.view(-1, self.concat_dim)
        x = self.bn(x)
        x = self.dropout(x)
    
        return self.vehicle_map(x), self.counts(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleModel()
# model.load_state_dict(torch.load('/scratch/vr1059/left_image_checkpoint.pt'))
model = model.to(device)
map_criterion = nn.BCEWithLogitsLoss()
count_criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-4)
best_val_loss = 100

# %%
def train():
    model.train()
    labeled_trainset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=train_labeled_scene_index,
                                  transform=train_transform,
                                  extra_info=True
                                 )
    train_loader = torch.utils.data.DataLoader(labeled_trainset, batch_size=15, num_workers=15, shuffle=True, collate_fn=collate_fn)
    
    train_losses = []
    map_losses = []
    count_losses = []
    f = open(log_file_path, "a+")
    for i, (sample, bbox_bins, road_maps, bbs, target_count, _) in enumerate(train_loader):
        optimizer.zero_grad()

        sample = sample.to(device)
        bbox_bins = bbox_bins.to(device)
        target_count = target_count.to(device)
        
        y_vehicle, y_count = model(sample)
        
        map_loss = map_criterion(y_vehicle, bbox_bins.float())
        count_loss = count_criterion(y_count, target_count.float())
        loss = 0.99 * map_loss + 0.01 * count_loss
        
        loss.backward()
        optimizer.step()
        
        train_losses.append(loss.item())
        map_losses.append(map_loss.item())
        count_losses.append(count_loss.item())
        if i % 50 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, i * len(sample), len(train_loader.dataset),
                50. * i / len(train_loader), loss.item()))
            
    print("\nAverage Train Epoch Loss: ", np.mean(train_losses))
    print("Average Train Map Loss: ", np.mean(map_losses))
    print("Average Train Count Epoch Loss: ", np.mean(count_losses))
    
    f.write("\nAverage Train Epoch Loss: {}".format(np.mean(train_losses)))
    f.write("Average Train Map Loss: {}".format(np.mean(map_losses)))
    f.write("Average Train Count Epoch Loss: {}".format(np.mean(count_losses)))
    
    f.close()
    
            
def val():
    
    val_loader = torch.utils.data.DataLoader(labeled_valset, batch_size=15, num_workers=5, shuffle=True, collate_fn=collate_fn)
    model.eval()
    val_losses = []
    map_losses = []
    count_losses = []
    
    f = open(log_file_path, "a+")
    
    for i, (sample, bbox_bins, road_maps, bbs, target_count, _) in enumerate(val_loader):

        model.eval()

        sample = sample.to(device)
        bbox_bins = bbox_bins.to(device)
        target_count = target_count.to(device)

        with torch.no_grad():
            y_vehicle, y_count = model(sample)
        
            map_loss = map_criterion(y_vehicle, bbox_bins.float())
            count_loss = count_criterion(y_count, target_count.float())
            loss = 0.99 * map_loss + 0.01 * count_loss
            
            val_losses.append(loss.item())
            map_losses.append(map_loss.item())
            count_losses.append(count_loss.item())
            
    print("\tAverage Validation Epoch Loss: ", np.mean(val_losses))
    print("\tAverage Validation Map Epoch Loss: ", np.mean(map_losses))
    print("\tAverage Validation Count Epoch Loss: ", np.mean(count_losses))
    
    f.write("\nAverage Validation Epoch Loss: {}".format(np.mean(val_losses)))
    f.write("\tAverage Validation Map Epoch Loss: {}".format(np.mean(map_losses)))
    f.write("\tAverage Validation Count Epoch Loss: {}".format(np.mean(count_losses)))

    global best_val_loss
    if np.mean(map_losses) < best_val_loss:
        best_val_loss = np.mean(map_losses)
        f.write("\n best_val_loss so far: {}".format(best_val_loss))
        torch.save(model.state_dict(), '/scratch/vr1059/left_image_lambda_10_by_10_0.95.pt')
        
    f.close()

# %%
log_file_path = "left_image_10_by_10_0.95.log"

# %%
epochs = 50
for epoch in range(epochs):
    train()
    val()
# Out:
# Train Epoch: 0 [0/3276 (0%)]	Loss: 0.728063
# Train Epoch: 0 [750/3276 (11%)]	Loss: 0.703905
# Train Epoch: 0 [1500/3276 (23%)]	Loss: 0.690192
# Train Epoch: 0 [2250/3276 (34%)]	Loss: 0.665331
# Train Epoch: 0 [3000/3276 (46%)]	Loss: 0.645206
#
# Average Train Epoch Loss:  0.6826721242029373
# Average Train Map Loss:  0.6826204782751597
# Average Train Count Epoch Loss:  0.687784378387068
# 	Average Validation Epoch Loss:  0.6205854976878447
# 	Average Validation Map Epoch Loss:  0.6204207714866189
# 	Average Validation Count Epoch Loss:  0.6368930024259231
# Train Epoch: 1 [0/3276 (0%)]	Loss: 0.625252
# Train Epoch: 1 [750/3276 (11%)]	Loss: 0.591748
# Train Epoch: 1 [1500/3276 (23%)]	Loss: 0.541583
# Train Epoch: 1 [2250/3276 (34%)]	Loss: 0.488265
# Train Epoch: 1 [3000/3276 (46%)]	Loss: 0.396505
#
# Average Train Epoch Loss:  0.5200345037190337
# Average Train Map Loss:  0.5195716179941343
# Average Train Count Epoch Loss:  0.5658594467868544
# 	Average Validation Epoch Loss:  0.38478174630333395
# 	Average Validation Map Epoch Loss:  0.38385612649076123
# 	Average Validation Count Epoch Loss:  0.47641758007161755
# Train Epoch: 2 [0/3276 (0%)]	Loss: 0.389579
# Train Epoch: 2 [750/3276 (11%)]	Loss: 0.337521
# Train Epoch: 2 [1500/3276 (23%)]	Loss: 0.278621
# Train Epoch: 2 [2250/3276 (34%)]	Loss: 0.237104
# Train Epoch: 2 [3000/3276 (46%)]	Loss: 0.190768
#
# Average Train Epoch Loss:  0.2716790933723319
# Average Train Map Loss:  0.2703830546712222
# Average Train Count Epoch Loss:  0.3999866962977196
# 	Average Validation Epoch Loss:  0.1731738202712115
# 	Average Validation Map Epoch Loss:  0.17157786120386684
# 	Average Validation Count Epoch Loss:  0.3311735146185931
# Train Epoch: 3 [0/3276 (0%)]	Loss: 0.174529
# Train Epoch: 3 [750/3276 (11%)]	Loss: 0.144053
# Train Epoch: 3 [1500/3276 (23%)]	Loss: 0.130568
# Train Epoch: 3 [2250/3276 (34%)]	Loss: 0.126522
# Train Epoch: 3 [3000/3276 (46%)]	Loss: 0.087721
#
# Average Train Epoch Loss:  0.12519796471617536
# Average Train Map Loss:  0.12336876549541134
# Average Train Count Epoch Loss:  0.30628856063977766
# 	Average Validation Epoch Loss:  0.08403249391738106
# 	Average Validation Map Epoch Loss:  0.08216727262034136
# 	Average Validation Count Epoch Loss:  0.2686893904910368
# Train Epoch: 4 [0/3276 (0%)]	Loss: 0.083937
# Train Epoch: 4 [750/3276 (11%)]	Loss: 0.077274
# Train Epoch: 4 [1500/3276 (23%)]	Loss: 0.065786
# Train Epoch: 4 [2250/3276 (34%)]	Loss: 0.060138
# Train Epoch: 4 [3000/3276 (46%)]	Loss: 0.054134
#
# Average Train Epoch Loss:  0.06561398953539596
# Average Train Map Loss:  0.06352815644381797
# Average Train Count Epoch Loss:  0.27211143464258275
# 	Average Validation Epoch Loss:  0.047906771302223206
# 	Average Validation Map Epoch Loss:  0.04591931030154228
# 	Average Validation Count Epoch Loss:  0.2446653352064245
# Train Epoch: 5 [0/3276 (0%)]	Loss: 0.042908
# Train Epoch: 5 [750/3276 (11%)]	Loss: 0.045309
# Train Epoch: 5 [1500/3276 (23%)]	Loss: 0.039364
# Train Epoch: 5 [2250/3276 (34%)]	Loss: 0.032367
# Train Epoch: 5 [3000/3276 (46%)]	Loss: 0.031004
#
# Average Train Epoch Loss:  0.03988836621482895
# Average Train Map Loss:  0.03768419921738372
# Average Train Count Epoch Loss:  0.2581008550919354
# 	Average Validation Epoch Loss:  0.03014516118256485
# 	Average Validation Map Epoch Loss:  0.02808792713810416
# 	Average Validation Count Epoch Loss:  0.23381131098550909
# Train Epoch: 6 [0/3276 (0%)]	Loss: 0.030792
# Train Epoch: 6 [750/3276 (11%)]	Loss: 0.030443
# Train Epoch: 6 [1500/3276 (23%)]	Loss: 0.025411
# Train Epoch: 6 [2250/3276 (34%)]	Loss: 0.031259
# Train Epoch: 6 [3000/3276 (46%)]	Loss: 0.023502
#
# Average Train Epoch Loss:  0.02757004538729583
# Average Train Map Loss:  0.025307750958762212
# Average Train Count Epoch Loss:  0.25153719235772953
# 	Average Validation Epoch Loss:  0.02206962730954675
# 	Average Validation Map Epoch Loss:  0.019978717846028945
# 	Average Validation Count Epoch Loss:  0.2290696449139539
# Train Epoch: 7 [0/3276 (0%)]	Loss: 0.022429
# Train Epoch: 7 [750/3276 (11%)]	Loss: 0.020673
# Train Epoch: 7 [1500/3276 (23%)]	Loss: 0.018980
# Train Epoch: 7 [2250/3276 (34%)]	Loss: 0.024098
# Train Epoch: 7 [3000/3276 (46%)]	Loss: 0.019296
#
# Average Train Epoch Loss:  0.020939000006169762
# Average Train Map Loss:  0.018647459433435307
# Average Train Count Epoch Loss:  0.2478015098941925
# 	Average Validation Epoch Loss:  0.017297208966577753
# 	Average Validation Map Epoch Loss:  0.015202311086742318
# 	Average Validation Count Epoch Loss:  0.2246921141357983
# Train Epoch: 8 [0/3276 (0%)]	Loss: 0.022467
# Train Epoch: 8 [750/3276 (11%)]	Loss: 0.019164
# Train Epoch: 8 [1500/3276 (23%)]	Loss: 0.016717
# Train Epoch: 8 [2250/3276 (34%)]	Loss: 0.019345
# Train Epoch: 8 [3000/3276 (46%)]	Loss: 0.015366
#
# Average Train Epoch Loss:  0.016754445186114474
# Average Train Map Loss:  0.014434621975540298
# Average Train Count Epoch Loss:  0.24641693495724298
# 	Average Validation Epoch Loss:  0.01410196053192896
# 	Average Validation Map Epoch Loss:  0.011976646095076027
# 	Average Validation Count Epoch Loss:  0.22450808216543758
# Train Epoch: 9 [0/3276 (0%)]	Loss: 0.017343
# Train Epoch: 9 [750/3276 (11%)]	Loss: 0.012477
# Train Epoch: 9 [1500/3276 (23%)]	Loss: 0.015380
# Train Epoch: 9 [2250/3276 (34%)]	Loss: 0.014725
# Train Epoch: 9 [3000/3276 (46%)]	Loss: 0.011356
#
# Average Train Epoch Loss:  0.01418629497902034
# Average Train Map Loss:  0.01183972604462205
# Average Train Count Epoch Loss:  0.24649661411977794
# 	Average Validation Epoch Loss:  0.012258870362797204
# 	Average Validation Map Epoch Loss:  0.010118780109812231
# 	Average Validation Count Epoch Loss:  0.22412779927253723
# Train Epoch: 10 [0/3276 (0%)]	Loss: 0.013326
# Train Epoch: 10 [750/3276 (11%)]	Loss: 0.011383
# Train Epoch: 10 [1500/3276 (23%)]	Loss: 0.012318
# Train Epoch: 10 [2250/3276 (34%)]	Loss: 0.010975
# Train Epoch: 10 [3000/3276 (46%)]	Loss: 0.008554
#
# Average Train Epoch Loss:  0.012424999826745083
# Average Train Map Loss:  0.010084189602161108
# Average Train Count Epoch Loss:  0.24416520620045595
# 	Average Validation Epoch Loss:  0.01076125753495623
# 	Average Validation Map Epoch Loss:  0.00860323354273158
# 	Average Validation Count Epoch Loss:  0.22440561915145202
# Train Epoch: 11 [0/3276 (0%)]	Loss: 0.014738
# Train Epoch: 11 [750/3276 (11%)]	Loss: 0.010231
# Train Epoch: 11 [1500/3276 (23%)]	Loss: 0.011625
# Train Epoch: 11 [2250/3276 (34%)]	Loss: 0.009835
# Train Epoch: 11 [3000/3276 (46%)]	Loss: 0.010524
#
# Average Train Epoch Loss:  0.011000861534976389
# Average Train Map Loss:  0.008673794799352482
# Average Train Count Epoch Loss:  0.24138046528922913
# 	Average Validation Epoch Loss:  0.009885540615548105
# 	Average Validation Map Epoch Loss:  0.007760846905191155
# 	Average Validation Count Epoch Loss:  0.22023022525450764
# Train Epoch: 12 [0/3276 (0%)]	Loss: 0.010926
# Train Epoch: 12 [750/3276 (11%)]	Loss: 0.010665
# Train Epoch: 12 [1500/3276 (23%)]	Loss: 0.009201
# Train Epoch: 12 [2250/3276 (34%)]	Loss: 0.008682
# Train Epoch: 12 [3000/3276 (46%)]	Loss: 0.010066
#
# Average Train Epoch Loss:  0.010139626216942862
# Average Train Map Loss:  0.0078007442085710295
# Average Train Count Epoch Loss:  0.24168894722309286
# 	Average Validation Epoch Loss:  0.009055016014505835
# 	Average Validation Map Epoch Loss:  0.0068807079018477135
# 	Average Validation Count Epoch Loss:  0.22431152883697958
# Train Epoch: 13 [0/3276 (0%)]	Loss: 0.011336
# Train Epoch: 13 [750/3276 (11%)]	Loss: 0.007852
# Train Epoch: 13 [1500/3276 (23%)]	Loss: 0.009341
# Train Epoch: 13 [2250/3276 (34%)]	Loss: 0.008407
# Train Epoch: 13 [3000/3276 (46%)]	Loss: 0.012139
#
# Average Train Epoch Loss:  0.009311691602717524
# Average Train Map Loss:  0.007019999311582002
# Average Train Count Epoch Loss:  0.23618922875896436
# 	Average Validation Epoch Loss:  0.008136149276705348
# 	Average Validation Map Epoch Loss:  0.005986369954531684
# 	Average Validation Count Epoch Loss:  0.2209642932695501
# Train Epoch: 14 [0/3276 (0%)]	Loss: 0.008407
# Train Epoch: 14 [750/3276 (11%)]	Loss: 0.008653
# Train Epoch: 14 [1500/3276 (23%)]	Loss: 0.010231
# Train Epoch: 14 [2250/3276 (34%)]	Loss: 0.006858
# Train Epoch: 14 [3000/3276 (46%)]	Loss: 0.008103
#
# Average Train Epoch Loss:  0.008658943096065222
# Average Train Map Loss:  0.006444707068457315
# Average Train Count Epoch Loss:  0.22786830869167363
# 	Average Validation Epoch Loss:  0.008044865831513615
# 	Average Validation Map Epoch Loss:  0.0057655967333737545
# 	Average Validation Count Epoch Loss:  0.23369249964461608
# Train Epoch: 15 [0/3276 (0%)]	Loss: 0.010114
# Train Epoch: 15 [750/3276 (11%)]	Loss: 0.008097
# Train Epoch: 15 [1500/3276 (23%)]	Loss: 0.006810
# Train Epoch: 15 [2250/3276 (34%)]	Loss: 0.008068
# Train Epoch: 15 [3000/3276 (46%)]	Loss: 0.006848
#
# Average Train Epoch Loss:  0.007842127295406578
# Average Train Map Loss:  0.005818347753871861
# Average Train Count Epoch Loss:  0.20819630313953852
# 	Average Validation Epoch Loss:  0.006917332107310786
# 	Average Validation Map Epoch Loss:  0.005265473675749758
# 	Average Validation Count Epoch Loss:  0.170451324652223
# Train Epoch: 16 [0/3276 (0%)]	Loss: 0.007566
# Train Epoch: 16 [750/3276 (11%)]	Loss: 0.007384
# Train Epoch: 16 [1500/3276 (23%)]	Loss: 0.005406
# Train Epoch: 16 [2250/3276 (34%)]	Loss: 0.009170
# Train Epoch: 16 [3000/3276 (46%)]	Loss: 0.006444
#
# Average Train Epoch Loss:  0.007253435153310022
# Average Train Map Loss:  0.005367916057175493
# Average Train Count Epoch Loss:  0.19391982407058211
# 	Average Validation Epoch Loss:  0.00695110550698112
# 	Average Validation Map Epoch Loss:  0.0052243086016353435
# 	Average Validation Count Epoch Loss:  0.17790400631287517
# Train Epoch: 17 [0/3276 (0%)]	Loss: 0.007523
# Train Epoch: 17 [750/3276 (11%)]	Loss: 0.006545
# Train Epoch: 17 [1500/3276 (23%)]	Loss: 0.006849
# Train Epoch: 17 [2250/3276 (34%)]	Loss: 0.006614
# Train Epoch: 17 [3000/3276 (46%)]	Loss: 0.004740
#
# Average Train Epoch Loss:  0.006620912904081415
# Average Train Map Loss:  0.0049030007847657075
# Average Train Count Epoch Loss:  0.17669421046564024
# 	Average Validation Epoch Loss:  0.005946597084403038
# 	Average Validation Map Epoch Loss:  0.00457130278022412
# 	Average Validation Count Epoch Loss:  0.1421007364988327
# Train Epoch: 18 [0/3276 (0%)]	Loss: 0.005485
# Train Epoch: 18 [750/3276 (11%)]	Loss: 0.005096
# Train Epoch: 18 [1500/3276 (23%)]	Loss: 0.006064
# Train Epoch: 18 [2250/3276 (34%)]	Loss: 0.007447
# Train Epoch: 18 [3000/3276 (46%)]	Loss: 0.004498
#
# Average Train Epoch Loss:  0.00614769595194625
# Average Train Map Loss:  0.004539197700982701
# Average Train Count Epoch Loss:  0.16538902463978283
# 	Average Validation Epoch Loss:  0.005753829006982201
# 	Average Validation Map Epoch Loss:  0.004458776154719731
# 	Average Validation Count Epoch Loss:  0.13396406349013834
# Train Epoch: 19 [0/3276 (0%)]	Loss: 0.006418
# Train Epoch: 19 [750/3276 (11%)]	Loss: 0.005374
# Train Epoch: 19 [1500/3276 (23%)]	Loss: 0.003878
# Train Epoch: 19 [2250/3276 (34%)]	Loss: 0.004336
# Train Epoch: 19 [3000/3276 (46%)]	Loss: 0.004610
#
# Average Train Epoch Loss:  0.005802089759875855
# Average Train Map Loss:  0.004280104746268084
# Average Train Count Epoch Loss:  0.1564786037829913
# 	Average Validation Epoch Loss:  0.005657814771813505
# 	Average Validation Map Epoch Loss:  0.00436743870651459
# 	Average Validation Count Epoch Loss:  0.13340504642795115
# Train Epoch: 20 [0/3276 (0%)]	Loss: 0.005814
# Train Epoch: 20 [750/3276 (11%)]	Loss: 0.004169
# Train Epoch: 20 [1500/3276 (23%)]	Loss: 0.003604
# Train Epoch: 20 [2250/3276 (34%)]	Loss: 0.003776
# Train Epoch: 20 [3000/3276 (46%)]	Loss: 0.006122
#
# Average Train Epoch Loss:  0.005405327006451547
# Average Train Map Loss:  0.004004293791184279
# Average Train Count Epoch Loss:  0.14410761492029173
# 	Average Validation Epoch Loss:  0.005527108263991335
# 	Average Validation Map Epoch Loss:  0.004222091807819465
# 	Average Validation Count Epoch Loss:  0.13472373827415354
# Train Epoch: 21 [0/3276 (0%)]	Loss: 0.003935
# Train Epoch: 21 [750/3276 (11%)]	Loss: 0.005524
# Train Epoch: 21 [1500/3276 (23%)]	Loss: 0.003412
# Train Epoch: 21 [2250/3276 (34%)]	Loss: 0.004126
# Train Epoch: 21 [3000/3276 (46%)]	Loss: 0.004562
#
# Average Train Epoch Loss:  0.005107818590264478
# Average Train Map Loss:  0.0037879520818829265
# Average Train Count Epoch Loss:  0.13577460310502684
# 	Average Validation Epoch Loss:  0.005050825009889463
# 	Average Validation Map Epoch Loss:  0.003911514232373413
# 	Average Validation Count Epoch Loss:  0.11784259449033176
# Train Epoch: 22 [0/3276 (0%)]	Loss: 0.006289
# Train Epoch: 22 [750/3276 (11%)]	Loss: 0.004403
# Train Epoch: 22 [1500/3276 (23%)]	Loss: 0.004231
# Train Epoch: 22 [2250/3276 (34%)]	Loss: 0.003988
# Train Epoch: 22 [3000/3276 (46%)]	Loss: 0.004035
#
# Average Train Epoch Loss:  0.004780966664141376
# Average Train Map Loss:  0.0035514469299950217
# Average Train Count Epoch Loss:  0.12650342028775172
# 	Average Validation Epoch Loss:  0.0050982445314088284
# 	Average Validation Map Epoch Loss:  0.00386106752900078
# 	Average Validation Count Epoch Loss:  0.12757876734523213
# Train Epoch: 23 [0/3276 (0%)]	Loss: 0.003568
# Train Epoch: 23 [750/3276 (11%)]	Loss: 0.004180
# Train Epoch: 23 [1500/3276 (23%)]	Loss: 0.005451
# Train Epoch: 23 [2250/3276 (34%)]	Loss: 0.004574
# Train Epoch: 23 [3000/3276 (46%)]	Loss: 0.003190
#
# Average Train Epoch Loss:  0.004559843066322817
# Average Train Map Loss:  0.003353465209740584
# Average Train Count Epoch Loss:  0.1239912511108945
# 	Average Validation Epoch Loss:  0.005287271266912713
# 	Average Validation Map Epoch Loss:  0.0038504613399067346
# 	Average Validation Count Epoch Loss:  0.14753144672688315
# Train Epoch: 24 [0/3276 (0%)]	Loss: 0.003823
# Train Epoch: 24 [750/3276 (11%)]	Loss: 0.004365
# Train Epoch: 24 [1500/3276 (23%)]	Loss: 0.007903
# Train Epoch: 24 [2250/3276 (34%)]	Loss: 0.003185
# Train Epoch: 24 [3000/3276 (46%)]	Loss: 0.005574
#
# Average Train Epoch Loss:  0.004356296259918373
# Average Train Map Loss:  0.0031916698968233585
# Average Train Count Epoch Loss:  0.11965430539832812
# 	Average Validation Epoch Loss:  0.004631788360283655
# 	Average Validation Map Epoch Loss:  0.0035128223654978417
# 	Average Validation Count Epoch Loss:  0.11540942639112473
# Train Epoch: 25 [0/3276 (0%)]	Loss: 0.002573
# Train Epoch: 25 [750/3276 (11%)]	Loss: 0.007135
# Train Epoch: 25 [1500/3276 (23%)]	Loss: 0.002488
# Train Epoch: 25 [2250/3276 (34%)]	Loss: 0.003123
# Train Epoch: 25 [3000/3276 (46%)]	Loss: 0.003658
#
# Average Train Epoch Loss:  0.0040755178534838295
# Average Train Map Loss:  0.0030150297188229823
# Average Train Count Epoch Loss:  0.10906384291646143
# 	Average Validation Epoch Loss:  0.004423139835981762
# 	Average Validation Map Epoch Loss:  0.0033415239030385718
# 	Average Validation Count Epoch Loss:  0.1115031134994591
# Train Epoch: 26 [0/3276 (0%)]	Loss: 0.003853
# Train Epoch: 26 [750/3276 (11%)]	Loss: 0.004136
# Train Epoch: 26 [1500/3276 (23%)]	Loss: 0.004069
# Train Epoch: 26 [2250/3276 (34%)]	Loss: 0.002340
# Train Epoch: 26 [3000/3276 (46%)]	Loss: 0.002102
#
# Average Train Epoch Loss:  0.003929753862767902
# Average Train Map Loss:  0.0029013351203456997
# Average Train Count Epoch Loss:  0.10574320948695483
# 	Average Validation Epoch Loss:  0.004388959804440246
# 	Average Validation Map Epoch Loss:  0.003295869066599099
# 	Average Validation Count Epoch Loss:  0.1126049362561282
# Train Epoch: 27 [0/3276 (0%)]	Loss: 0.003243
# Train Epoch: 27 [750/3276 (11%)]	Loss: 0.002524
# Train Epoch: 27 [1500/3276 (23%)]	Loss: 0.002827
# Train Epoch: 27 [2250/3276 (34%)]	Loss: 0.002771
# Train Epoch: 27 [3000/3276 (46%)]	Loss: 0.001921
#
# Average Train Epoch Loss:  0.0037212490484747848
# Average Train Map Loss:  0.002763352993680122
# Average Train Count Epoch Loss:  0.09855295778953865
# 	Average Validation Epoch Loss:  0.004140271093038952
# 	Average Validation Map Epoch Loss:  0.0030621214126072384
# 	Average Validation Count Epoch Loss:  0.11087709227029015
# Train Epoch: 28 [0/3276 (0%)]	Loss: 0.003296
# Train Epoch: 28 [750/3276 (11%)]	Loss: 0.006485
# Train Epoch: 28 [1500/3276 (23%)]	Loss: 0.004021
# Train Epoch: 28 [2250/3276 (34%)]	Loss: 0.003605
# Train Epoch: 28 [3000/3276 (46%)]	Loss: 0.002842
#
# Average Train Epoch Loss:  0.0035428286548151067
# Average Train Map Loss:  0.0026500591217246774
# Average Train Count Epoch Loss:  0.09192701131445633
# 	Average Validation Epoch Loss:  0.004001624375472174
# 	Average Validation Map Epoch Loss:  0.0029976083075298984
# 	Average Validation Count Epoch Loss:  0.10339921690961894
# Train Epoch: 29 [0/3276 (0%)]	Loss: 0.004916
# Train Epoch: 29 [750/3276 (11%)]	Loss: 0.002381
# Train Epoch: 29 [1500/3276 (23%)]	Loss: 0.005290
# Train Epoch: 29 [2250/3276 (34%)]	Loss: 0.003754
# Train Epoch: 29 [3000/3276 (46%)]	Loss: 0.002174
#
# Average Train Epoch Loss:  0.003372369936378205
# Average Train Map Loss:  0.002522511256233572
# Average Train Count Epoch Loss:  0.08750837895866126
# 	Average Validation Epoch Loss:  0.003908067407524761
# 	Average Validation Map Epoch Loss:  0.0028963923276237704
# 	Average Validation Count Epoch Loss:  0.10406388999784694
# Train Epoch: 30 [0/3276 (0%)]	Loss: 0.002448
# Train Epoch: 30 [750/3276 (11%)]	Loss: 0.002916
# Train Epoch: 30 [1500/3276 (23%)]	Loss: 0.002261
# Train Epoch: 30 [2250/3276 (34%)]	Loss: 0.004194
# Train Epoch: 30 [3000/3276 (46%)]	Loss: 0.003628
#
# Average Train Epoch Loss:  0.0031878837175905433
# Average Train Map Loss:  0.0024236761712358593
# Average Train Count Epoch Loss:  0.07884442999312595
# 	Average Validation Epoch Loss:  0.0035181958639227294
# 	Average Validation Map Epoch Loss:  0.002679373185588595
# 	Average Validation Count Epoch Loss:  0.0865616434637238
# Train Epoch: 31 [0/3276 (0%)]	Loss: 0.002389
# Train Epoch: 31 [750/3276 (11%)]	Loss: 0.003130
# Train Epoch: 31 [1500/3276 (23%)]	Loss: 0.003196
# Train Epoch: 31 [2250/3276 (34%)]	Loss: 0.001538
# Train Epoch: 31 [3000/3276 (46%)]	Loss: 0.002698
#
# Average Train Epoch Loss:  0.003029280074778519
# Average Train Map Loss:  0.0023053758660731114
# Average Train Count Epoch Loss:  0.07469579694818144
# 	Average Validation Epoch Loss:  0.004124326467075769
# 	Average Validation Map Epoch Loss:  0.0027828678584602825
# 	Average Validation Count Epoch Loss:  0.13692873299998395
# Train Epoch: 32 [0/3276 (0%)]	Loss: 0.003934
# Train Epoch: 32 [750/3276 (11%)]	Loss: 0.002756
# Train Epoch: 32 [1500/3276 (23%)]	Loss: 0.003681
# Train Epoch: 32 [2250/3276 (34%)]	Loss: 0.003637
# Train Epoch: 32 [3000/3276 (46%)]	Loss: 0.002513
#
# Average Train Epoch Loss:  0.0028405859311574806
# Average Train Map Loss:  0.002219990877908778
# Average Train Count Epoch Loss:  0.06427949578522547
# 	Average Validation Epoch Loss:  0.0035552692955688517
# 	Average Validation Map Epoch Loss:  0.0025724746108822085
# 	Average Validation Count Epoch Loss:  0.1008519440451089
# Train Epoch: 33 [0/3276 (0%)]	Loss: 0.002097
# Train Epoch: 33 [750/3276 (11%)]	Loss: 0.003248
# Train Epoch: 33 [1500/3276 (23%)]	Loss: 0.004425
# Train Epoch: 33 [2250/3276 (34%)]	Loss: 0.001482
# Train Epoch: 33 [3000/3276 (46%)]	Loss: 0.002200
#
# Average Train Epoch Loss:  0.0028312273119410424
# Average Train Map Loss:  0.002156621546082658
# Average Train Count Epoch Loss:  0.06961719632216784
# 	Average Validation Epoch Loss:  0.0033567576422629986
# 	Average Validation Map Epoch Loss:  0.0024142268127487865
# 	Average Validation Count Epoch Loss:  0.09666730803163613
# Train Epoch: 34 [0/3276 (0%)]	Loss: 0.004007
# Train Epoch: 34 [750/3276 (11%)]	Loss: 0.002800
# Train Epoch: 34 [1500/3276 (23%)]	Loss: 0.002621
# Train Epoch: 34 [2250/3276 (34%)]	Loss: 0.004423
# Train Epoch: 34 [3000/3276 (46%)]	Loss: 0.002078
#
# Average Train Epoch Loss:  0.002660780645413622
# Average Train Map Loss:  0.0020684019755997343
# Average Train Count Epoch Loss:  0.06130626845305369
# 	Average Validation Epoch Loss:  0.003762068993905011
# 	Average Validation Map Epoch Loss:  0.0025685604743878633
# 	Average Validation Count Epoch Loss:  0.12191941238501493
# Train Epoch: 35 [0/3276 (0%)]	Loss: 0.005054
# Train Epoch: 35 [750/3276 (11%)]	Loss: 0.003651
# Train Epoch: 35 [1500/3276 (23%)]	Loss: 0.002343
# Train Epoch: 35 [2250/3276 (34%)]	Loss: 0.002156
# Train Epoch: 35 [3000/3276 (46%)]	Loss: 0.002078
#
# Average Train Epoch Loss:  0.0024758275916170517
# Average Train Map Loss:  0.0019848683012275185
# Average Train Count Epoch Loss:  0.05108079625948515
# 	Average Validation Epoch Loss:  0.0034010162412682
# 	Average Validation Map Epoch Loss:  0.0023956569254069645
# 	Average Validation Count Epoch Loss:  0.10293158636811901
# Train Epoch: 36 [0/3276 (0%)]	Loss: 0.001977
# Train Epoch: 36 [750/3276 (11%)]	Loss: 0.001322
# Train Epoch: 36 [1500/3276 (23%)]	Loss: 0.001334
# Train Epoch: 36 [2250/3276 (34%)]	Loss: 0.003296
# Train Epoch: 36 [3000/3276 (46%)]	Loss: 0.001430
#
# Average Train Epoch Loss:  0.002378114680685188
# Average Train Map Loss:  0.0019037024839355964
# Average Train Count Epoch Loss:  0.04934492130597977
# 	Average Validation Epoch Loss:  0.0036289917359895564
# 	Average Validation Map Epoch Loss:  0.002543917706455378
# 	Average Validation Count Epoch Loss:  0.11105132135836517
# Train Epoch: 37 [0/3276 (0%)]	Loss: 0.001368
# Train Epoch: 37 [750/3276 (11%)]	Loss: 0.002502
# Train Epoch: 37 [1500/3276 (23%)]	Loss: 0.005463
# Train Epoch: 37 [2250/3276 (34%)]	Loss: 0.001281
# Train Epoch: 37 [3000/3276 (46%)]	Loss: 0.004210
#
# Average Train Epoch Loss:  0.0023236353751420803
# Average Train Map Loss:  0.0018629675503016438
# Average Train Count Epoch Loss:  0.04792974995593774
# 	Average Validation Epoch Loss:  0.003721801221699399
# 	Average Validation Map Epoch Loss:  0.0024493891910156783
# 	Average Validation Count Epoch Loss:  0.12969059146502437
# Train Epoch: 38 [0/3276 (0%)]	Loss: 0.001639
# Train Epoch: 38 [750/3276 (11%)]	Loss: 0.004281
# Train Epoch: 38 [1500/3276 (23%)]	Loss: 0.001603
# Train Epoch: 38 [2250/3276 (34%)]	Loss: 0.001642
# Train Epoch: 38 [3000/3276 (46%)]	Loss: 0.005821
#
# Average Train Epoch Loss:  0.00220273512353925
# Average Train Map Loss:  0.0017822608038077139
# Average Train Count Epoch Loss:  0.043829691872749155
# 	Average Validation Epoch Loss:  0.003376751617692849
# 	Average Validation Map Epoch Loss:  0.0023649155696415726
# 	Average Validation Count Epoch Loss:  0.10354852490127087
# Train Epoch: 39 [0/3276 (0%)]	Loss: 0.002124
# Train Epoch: 39 [750/3276 (11%)]	Loss: 0.002712
# Train Epoch: 39 [1500/3276 (23%)]	Loss: 0.001835
# Train Epoch: 39 [2250/3276 (34%)]	Loss: 0.001935
# Train Epoch: 39 [3000/3276 (46%)]	Loss: 0.003429
#
# Average Train Epoch Loss:  0.002211294531637216
# Average Train Map Loss:  0.0017918151939929927
# Average Train Count Epoch Loss:  0.04373974786841706
# 	Average Validation Epoch Loss:  0.003333137247382718
# 	Average Validation Map Epoch Loss:  0.0023277774453163147
# 	Average Validation Count Epoch Loss:  0.10286375420058474
# Train Epoch: 40 [0/3276 (0%)]	Loss: 0.001823
# Train Epoch: 40 [750/3276 (11%)]	Loss: 0.002883
# Train Epoch: 40 [1500/3276 (23%)]	Loss: 0.001728
# Train Epoch: 40 [2250/3276 (34%)]	Loss: 0.001352
# Train Epoch: 40 [3000/3276 (46%)]	Loss: 0.001558
#
# Average Train Epoch Loss:  0.0019769372060240062
# Average Train Map Loss:  0.0016670350278259922
# Average Train Count Epoch Loss:  0.032657251720950346
# 	Average Validation Epoch Loss:  0.0031098094015546583
# 	Average Validation Map Epoch Loss:  0.002139849033590187
# 	Average Validation Count Epoch Loss:  0.09913589054828181
# Train Epoch: 41 [0/3276 (0%)]	Loss: 0.001944
# Train Epoch: 41 [750/3276 (11%)]	Loss: 0.001048
# Train Epoch: 41 [1500/3276 (23%)]	Loss: 0.002775
# Train Epoch: 41 [2250/3276 (34%)]	Loss: 0.002381
# Train Epoch: 41 [3000/3276 (46%)]	Loss: 0.001514
#
# Average Train Epoch Loss:  0.001994020401789343
# Average Train Map Loss:  0.0016420583235903655
# Average Train Count Epoch Loss:  0.036838266011922874
# 	Average Validation Epoch Loss:  0.003224797492079875
# 	Average Validation Map Epoch Loss:  0.0022924452513346776
# 	Average Validation Count Epoch Loss:  0.09552766749744906
# Train Epoch: 42 [0/3276 (0%)]	Loss: 0.001501
# Train Epoch: 42 [750/3276 (11%)]	Loss: 0.003085
# Train Epoch: 42 [1500/3276 (23%)]	Loss: 0.001146
# Train Epoch: 42 [2250/3276 (34%)]	Loss: 0.001766
# Train Epoch: 42 [3000/3276 (46%)]	Loss: 0.001329
#
# Average Train Epoch Loss:  0.001861820392922996
# Average Train Map Loss:  0.001578045569994959
# Average Train Count Epoch Loss:  0.02995552668841258
# 	Average Validation Epoch Loss:  0.003251804134753697
# 	Average Validation Map Epoch Loss:  0.002345611296785886
# 	Average Validation Count Epoch Loss:  0.09296489364522345
# Train Epoch: 43 [0/3276 (0%)]	Loss: 0.001320
# Train Epoch: 43 [750/3276 (11%)]	Loss: 0.001438
# Train Epoch: 43 [1500/3276 (23%)]	Loss: 0.001729
# Train Epoch: 43 [2250/3276 (34%)]	Loss: 0.001277
# Train Epoch: 43 [3000/3276 (46%)]	Loss: 0.002192
#
# Average Train Epoch Loss:  0.0019313594797885547
# Average Train Map Loss:  0.0015699008785902636
# Average Train Count Epoch Loss:  0.037715760240390826
# 	Average Validation Epoch Loss:  0.0033779756768661387
# 	Average Validation Map Epoch Loss:  0.0022416411255321957
# 	Average Validation Count Epoch Loss:  0.11587510214132421
# Train Epoch: 44 [0/3276 (0%)]	Loss: 0.002781
# Train Epoch: 44 [750/3276 (11%)]	Loss: 0.002050
# Train Epoch: 44 [1500/3276 (23%)]	Loss: 0.000880
# Train Epoch: 44 [2250/3276 (34%)]	Loss: 0.001608
# Train Epoch: 44 [3000/3276 (46%)]	Loss: 0.001878
#
# Average Train Epoch Loss:  0.001798918071260344
# Average Train Map Loss:  0.0015115978206363273
# Average Train Count Epoch Loss:  0.03024362194772861
# 	Average Validation Epoch Loss:  0.003506454954142956
# 	Average Validation Map Epoch Loss:  0.002337322344400865
# 	Average Validation Count Epoch Loss:  0.1192505835172008
# Train Epoch: 45 [0/3276 (0%)]	Loss: 0.001311
# Train Epoch: 45 [750/3276 (11%)]	Loss: 0.000879
# Train Epoch: 45 [1500/3276 (23%)]	Loss: 0.001550
# Train Epoch: 45 [2250/3276 (34%)]	Loss: 0.002445
# Train Epoch: 45 [3000/3276 (46%)]	Loss: 0.001540
#
# Average Train Epoch Loss:  0.0018217854911980291
# Average Train Map Loss:  0.0014904340132156633
# Average Train Count Epoch Loss:  0.03462558105103161
# 	Average Validation Epoch Loss:  0.003680553930975935
# 	Average Validation Map Epoch Loss:  0.0024074512150357753
# 	Average Validation Count Epoch Loss:  0.1297177181524389
# Train Epoch: 46 [0/3276 (0%)]	Loss: 0.003255
# Train Epoch: 46 [750/3276 (11%)]	Loss: 0.003839
# Train Epoch: 46 [1500/3276 (23%)]	Loss: 0.001771
# Train Epoch: 46 [2250/3276 (34%)]	Loss: 0.002980
# Train Epoch: 46 [3000/3276 (46%)]	Loss: 0.003773
#
# Average Train Epoch Loss:  0.0018432119177637376
# Average Train Map Loss:  0.001524653441493812
# Average Train Count Epoch Loss:  0.03338050063525127
# 	Average Validation Epoch Loss:  0.0033572967890102196
# 	Average Validation Map Epoch Loss:  0.002357618849012343
# 	Average Validation Count Epoch Loss:  0.10232541403349708
# Train Epoch: 47 [0/3276 (0%)]	Loss: 0.002276
# Train Epoch: 47 [750/3276 (11%)]	Loss: 0.001961
# Train Epoch: 47 [1500/3276 (23%)]	Loss: 0.002068
# Train Epoch: 47 [2250/3276 (34%)]	Loss: 0.002699
# Train Epoch: 47 [3000/3276 (46%)]	Loss: 0.002285
#
# Average Train Epoch Loss:  0.0016793726829675848
# Average Train Map Loss:  0.0014180784932599237
# Average Train Count Epoch Loss:  0.027547496387981662
# 	Average Validation Epoch Loss:  0.003660248448688756
# 	Average Validation Map Epoch Loss:  0.0024413351613261245
# 	Average Validation Count Epoch Loss:  0.12433267012238503
# Train Epoch: 48 [0/3276 (0%)]	Loss: 0.001831
# Train Epoch: 48 [750/3276 (11%)]	Loss: 0.001333
# Train Epoch: 48 [1500/3276 (23%)]	Loss: 0.000851
# Train Epoch: 48 [2250/3276 (34%)]	Loss: 0.000921
# Train Epoch: 48 [3000/3276 (46%)]	Loss: 0.002630
#
# Average Train Epoch Loss:  0.0016173572618658888
# Average Train Map Loss:  0.0013591182748011004
# Average Train Count Epoch Loss:  0.02718301638259157
# 	Average Validation Epoch Loss:  0.0039886730339597255
# 	Average Validation Map Epoch Loss:  0.002315879611106699
# 	Average Validation Count Epoch Loss:  0.16959522880942507
# Train Epoch: 49 [0/3276 (0%)]	Loss: 0.001625
# Train Epoch: 49 [750/3276 (11%)]	Loss: 0.002144
# Train Epoch: 49 [1500/3276 (23%)]	Loss: 0.001115
# Train Epoch: 49 [2250/3276 (34%)]	Loss: 0.001147
# Train Epoch: 49 [3000/3276 (46%)]	Loss: 0.001046
#
# Average Train Epoch Loss:  0.0016055514022801497
# Average Train Map Loss:  0.0013603511735261098
# Average Train Count Epoch Loss:  0.02588037371669458
# 	Average Validation Epoch Loss:  0.003333258949329748
# 	Average Validation Map Epoch Loss:  0.002239837763173615
# 	Average Validation Count Epoch Loss:  0.11158195702249513

# %%
# 0.00259 best val map loss. 
# I'm getting 0.3/0.4 iou_threshold scores like every time there's a car now. 
# I feel like if I do 0.9, 0.1 split, then we can focus more on map loss. 

# Next thing to do is 0.95, 0.05 split for map loss. 
# Got 0.2149 best val map loss. 

# Trying 0.99, 0.01 split now. 
# And also added an extra 100-MLP layer. 
# 0.00213 best val map loss. 

# Next thing to do is lr flips. 

# I might have to decrease hue, or not do it at all. 
# It might be messing up the model. All the bright colors and shit.
