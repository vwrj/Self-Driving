# %%
import os
import random
import math
import kornia
import numpy as np
import pandas as pd
import pdb
from collections import OrderedDict
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import collections  as mc
matplotlib.rcParams['figure.figsize'] = [6, 6]
matplotlib.rcParams['figure.dpi'] = 200

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms

from data_helper import UnlabeledDataset, LabeledDataset
from helper import draw_box

# random.seed(0)
# np.random.seed(0)
# torch.manual_seed(0);

# All the images are saved in image_folder
# All the labels are saved in the annotation_csv file
image_folder = '/scratch/brs426/data'
annotation_csv = '/scratch/brs426/data/annotation.csv'

# You shouldn't change the unlabeled_scene_index
# The first 106 scenes are unlabeled
unlabeled_scene_index = np.arange(106)
# The scenes from 106 - 133 are labeled
# You should devide the labeled_scene_index into two subsets (training and validation)
train_labeled_scene_index = np.arange(109, 134)
val_labeled_scene_index = np.arange(106, 109)
test_labeled_scene_index = np.arange(106, 109)

from helper import compute_ats_bounding_boxes, compute_ts_road_map
from utils.angles import within_angles

# %%
VERT_BLOCK_SIZE = 10
HORIZ_BLOCK_SIZE = 10
BLOCK_AREA = VERT_BLOCK_SIZE * HORIZ_BLOCK_SIZE

# %%
def blur(img):
    img = img.unsqueeze(0)
    blurred = kornia.filters.gaussian_blur2d(img, kernel_size=(3, 3), sigma=(9.5, 9.5))
    return blurred.squeeze(0)

# %%
def collate_fn(batch):
    left_images = []
    target = []
    road_maps = []
    bbox_maps = []
    bbox_bins = []
    bbs = []
    target_counts = []
    for x in batch:
        
        # Get road_image and cast it to float
        road_image = torch.as_tensor(x[2]).float()
        road_maps.append(road_image)
        
        # Collect front-left image.  
        # Try cutting off the top 130 pixels (that can lead to overfitting)
        image = torch.Tensor(x[0][4])[:, 130:, :]
        left_images.append(image)
        
        # target
        bb_tens = x[1]['bounding_box']
        current_bbs = []
        bbox_map = torch.zeros((800, 800))
        counts = np.zeros(60)
        count = 0
        
        # Create the bounding box map. 
        for i, corners in enumerate(bb_tens):
            
            # Grab the current bounding box. 
            current_bbs.append(corners)
            
            # Get its four bird's-eye view coordinates. 
            point_squence = torch.stack([corners[:, 0], corners[:, 1], corners[:, 3], corners[:, 2]])
            xs = point_squence.T[0] * 10 + 400
            ys = -point_squence.T[1] * 10 + 400
            
            # xs is horizontal, ys is vertical through. 
            # But we're doing things row, column way. 
            
            # Only get the bounding boxes that are close-by. On the same road. 
            # We want to see if the model can fucking predict cars that are close by. 
            
            center_x, center_y = torch.mean(xs).item(), torch.mean(ys).item()
            if within_angles(xs, ys, angle1=148, angle2=215) and \
                center_y > 255 and center_y < 500:
            
                # Grab the top-left coordinates. 
                r, c = int(torch.min(ys).item()), int(torch.min(xs).item())
                r_len, c_len = int(torch.max(ys).item()) - r, int(torch.max(xs).item()) - c

                # Fill in the bbox. 
                bbox_map[r:r+r_len, c:c+c_len] = 1.0

                count += 1
            
        # Convert the bounding box map into classes (5px by 5px bins)
        bbox_grid = []
        for x_ in range(0, 800, VERT_BLOCK_SIZE):
            for y in range(0, 800, HORIZ_BLOCK_SIZE):
                block = bbox_map[x_:x_+VERT_BLOCK_SIZE, y:y+HORIZ_BLOCK_SIZE]
                score = torch.sum(block).item()
                # If more than have the pixels are 1, classify as bbox car
                if score > 0.5 * (BLOCK_AREA):
                    bbox_grid.append(1.0)
                else:
                    bbox_grid.append(0.0)
                    
        bbox_bins.append(torch.Tensor(bbox_grid))
              
        counts[count] = 1

        # Label Smoothing #
#         if count > 15 and count < 88:
#             counts[count+1] = 0.2
#             counts[count-1] = 0.2
            
        target_counts.append(torch.Tensor(counts))
        
        bbox_maps.append(bbox_map)

        bbs.append(current_bbs)
                
    boom = torch.stack(left_images), torch.stack(bbox_bins), torch.stack(road_maps), bbs, torch.stack(target_counts), torch.stack(bbox_maps) 
    return boom

# %%
val_transform = transforms.ToTensor()

train_transform = transforms.Compose([
    transforms.ColorJitter(brightness = 0.5, contrast = 0.5, saturation = 0.4, hue = (-0.5, 0.5)),
    transforms.RandomApply([
        transforms.Grayscale(3),
#         transforms.RandomAffine(1),
    ]),
    transforms.ToTensor(),
    transforms.RandomApply([
        transforms.Lambda(lambda img: blur(img)),
    ])
])

labeled_trainset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=train_labeled_scene_index,
                                  transform=train_transform,
                                  extra_info=True
                                 )

labeled_valset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=val_labeled_scene_index,
                                  transform=val_transform,
                                  extra_info=True
                                 )

# %% [markdown]
# #### Testing

# %%
train_loader = torch.utils.data.DataLoader(labeled_trainset, batch_size=16, shuffle=True, collate_fn=collate_fn)

# %%
# Compute threat scores
def reconstruct_from_bins(bins, threshold):
    print(bins.shape)
    road_map = torch.zeros((800, 800))
    idx = 0
    for x in range(0, 800, VERT_BLOCK_SIZE):
        for y in range(0, 800, HORIZ_BLOCK_SIZE):
            road_map[x:x+VERT_BLOCK_SIZE, y:y+HORIZ_BLOCK_SIZE] = bins[idx]
            idx += 1
    return road_map > threshold

# %%
sample, bbox_bins, road_maps, bbs, counts, bbox_maps  = iter(train_loader).next()

# %%
idx = -1

# %%
idx += 1

# %%
print(torch.argmax(counts[idx]))
matplotlib.rcParams['figure.figsize'] = [5,5]
plt.imshow(sample[idx].numpy().transpose(1, 2, 0))
plt.axis('off');
# Out:
# tensor(5)

# %%
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [3,3]
fig, ax = plt.subplots()
ax.imshow(road_maps[idx], cmap ='binary');
ax.plot(400, 400, 'x', color="red")
for bb in bbs[idx]:
    draw_box(ax, bb, 'orange')

# %%
threshold = 0.5
road_map = reconstruct_from_bins(bbox_bins[idx], threshold)
fig, ax = plt.subplots()
ax.imshow(road_map, cmap ='binary');
ax.plot(400, 400, 'x', color="red")
# Out:
# torch.Size([6400])

# %% [markdown]
# ### Model

# %%
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        
        self.encoder = torchvision.models.resnet18()
        self.encoder.fc = nn.Identity()
        self.concat_dim = 100
        self.dropout = nn.Dropout(p = 0.2)
        self.bn = nn.BatchNorm1d(self.concat_dim)
        
        self.compress = nn.Sequential(OrderedDict([
            ('linear0', nn.Linear(512, 100)),
            ('relu', nn.ReLU()),
        ]))
        
        self.vehicle_map = nn.Sequential(OrderedDict([
            ('linear1_vehicle', nn.Linear(self.concat_dim, 6400)),
        ]))
        
        self.counts = nn.Sequential(OrderedDict([
            ('count1', nn.Linear(self.concat_dim, 60))
        ]))
        
    def forward(self, x):
        
        batch_size = x.shape[0]
        channels = x.shape[1]
        height = x.shape[2]
        width = x.shape[3]
        # Reshape here
        x = x.view(-1, channels, height, width)
        x = self.encoder(x)
        x = self.compress(x)
        x = x.view(-1, self.concat_dim)
        x = self.bn(x)
        x = self.dropout(x)
    
        return self.vehicle_map(x), self.counts(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleModel()
# model.load_state_dict(torch.load('/scratch/vr1059/left_image_checkpoint.pt'))
model = model.to(device)
map_criterion = nn.BCEWithLogitsLoss()
count_criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-4)
best_val_loss = 100

# %%
def train():
    model.train()
    labeled_trainset = LabeledDataset(image_folder=image_folder,
                                  annotation_file=annotation_csv,
                                  scene_index=train_labeled_scene_index,
                                  transform=train_transform,
                                  extra_info=True
                                 )
    train_loader = torch.utils.data.DataLoader(labeled_trainset, batch_size=15, num_workers=15, shuffle=True, collate_fn=collate_fn)
    
    train_losses = []
    map_losses = []
    count_losses = []
    f = open(log_file_path, "a+")
    for i, (sample, bbox_bins, road_maps, bbs, target_count, _) in enumerate(train_loader):
        optimizer.zero_grad()

        sample = sample.to(device)
        bbox_bins = bbox_bins.to(device)
        target_count = target_count.to(device)
        
        y_vehicle, y_count = model(sample)
        
        map_loss = map_criterion(y_vehicle, bbox_bins.float())
        count_loss = count_criterion(y_count, target_count.float())
        loss = 0.99 * map_loss + 0.01 * count_loss
        
        loss.backward()
        optimizer.step()
        
        train_losses.append(loss.item())
        map_losses.append(map_loss.item())
        count_losses.append(count_loss.item())
        if i % 50 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, i * len(sample), len(train_loader.dataset),
                50. * i / len(train_loader), loss.item()))
            
    print("\nAverage Train Epoch Loss: ", np.mean(train_losses))
    print("Average Train Map Loss: ", np.mean(map_losses))
    print("Average Train Count Epoch Loss: ", np.mean(count_losses))
    
    f.write("\nAverage Train Epoch Loss: {}".format(np.mean(train_losses)))
    f.write("Average Train Map Loss: {}".format(np.mean(map_losses)))
    f.write("Average Train Count Epoch Loss: {}".format(np.mean(count_losses)))
    
    f.close()
    
            
def val():
    
    val_loader = torch.utils.data.DataLoader(labeled_valset, batch_size=15, num_workers=5, shuffle=True, collate_fn=collate_fn)
    model.eval()
    val_losses = []
    map_losses = []
    count_losses = []
    
    f = open(log_file_path, "a+")
    
    for i, (sample, bbox_bins, road_maps, bbs, target_count, _) in enumerate(val_loader):

        model.eval()

        sample = sample.to(device)
        bbox_bins = bbox_bins.to(device)
        target_count = target_count.to(device)

        with torch.no_grad():
            y_vehicle, y_count = model(sample)
        
            map_loss = map_criterion(y_vehicle, bbox_bins.float())
            count_loss = count_criterion(y_count, target_count.float())
            loss = 0.99 * map_loss + 0.01 * count_loss
            
            val_losses.append(loss.item())
            map_losses.append(map_loss.item())
            count_losses.append(count_loss.item())
            
    print("\tAverage Validation Epoch Loss: ", np.mean(val_losses))
    print("\tAverage Validation Map Epoch Loss: ", np.mean(map_losses))
    print("\tAverage Validation Count Epoch Loss: ", np.mean(count_losses))
    
    f.write("\nAverage Validation Epoch Loss: {}".format(np.mean(val_losses)))
    f.write("\tAverage Validation Map Epoch Loss: {}".format(np.mean(map_losses)))
    f.write("\tAverage Validation Count Epoch Loss: {}".format(np.mean(count_losses)))

    global best_val_loss
    if np.mean(map_losses) < best_val_loss:
        best_val_loss = np.mean(map_losses)
        f.write("\n best_val_loss so far: {}".format(best_val_loss))
        torch.save(model.state_dict(), '/scratch/vr1059/back_image_resnet18_val_new_gauss_3.pt')
        
    f.close()

# %%
log_file_path = "back_image_resnet_18_val_new_gauss_3.log"

# %%
epochs = 65
for epoch in range(epochs):
    train()
    val()
# Out:
# Train Epoch: 0 [0/3150 (0%)]	Loss: 0.724531
# Train Epoch: 0 [750/3150 (12%)]	Loss: 0.698417
# Train Epoch: 0 [1500/3150 (24%)]	Loss: 0.681157
# Train Epoch: 0 [2250/3150 (36%)]	Loss: 0.666161
# Train Epoch: 0 [3000/3150 (48%)]	Loss: 0.628953
#
# Average Train Epoch Loss:  0.6779266553265708
# Average Train Map Loss:  0.6779267498425074
# Average Train Count Epoch Loss:  0.677916837873913
# 	Average Validation Epoch Loss:  0.6234635619016794
# 	Average Validation Map Epoch Loss:  0.623398448412235
# 	Average Validation Count Epoch Loss:  0.6299084562521714
# Train Epoch: 1 [0/3150 (0%)]	Loss: 0.619647
# Train Epoch: 1 [750/3150 (12%)]	Loss: 0.575935
# Train Epoch: 1 [1500/3150 (24%)]	Loss: 0.529953
# Train Epoch: 1 [2250/3150 (36%)]	Loss: 0.466860
# Train Epoch: 1 [3000/3150 (48%)]	Loss: 0.397646
#
# Average Train Epoch Loss:  0.5190401612293153
# Average Train Map Loss:  0.5189887046813965
# Average Train Count Epoch Loss:  0.5241336591186978
# 	Average Validation Epoch Loss:  0.5585173528928024
# 	Average Validation Map Epoch Loss:  0.5581948504998133
# 	Average Validation Count Epoch Loss:  0.5904446118153058
# Train Epoch: 2 [0/3150 (0%)]	Loss: 0.405675
# Train Epoch: 2 [750/3150 (12%)]	Loss: 0.344006
# Train Epoch: 2 [1500/3150 (24%)]	Loss: 0.297503
# Train Epoch: 2 [2250/3150 (36%)]	Loss: 0.236475
# Train Epoch: 2 [3000/3150 (48%)]	Loss: 0.217442
#
# Average Train Epoch Loss:  0.29353153776554836
# Average Train Map Loss:  0.29339431063050314
# Average Train Count Epoch Loss:  0.30711679863078256
# 	Average Validation Epoch Loss:  0.18690625807413688
# 	Average Validation Map Epoch Loss:  0.1867345284957152
# 	Average Validation Count Epoch Loss:  0.20390717398661834
# Train Epoch: 3 [0/3150 (0%)]	Loss: 0.201888
# Train Epoch: 3 [750/3150 (12%)]	Loss: 0.168194
# Train Epoch: 3 [1500/3150 (24%)]	Loss: 0.144341
# Train Epoch: 3 [2250/3150 (36%)]	Loss: 0.133079
# Train Epoch: 3 [3000/3150 (48%)]	Loss: 0.114211
#
# Average Train Epoch Loss:  0.14829396708380607
# Average Train Map Loss:  0.1480830481719403
# Average Train Count Epoch Loss:  0.16917480812186286
# 	Average Validation Epoch Loss:  0.180315857896438
# 	Average Validation Map Epoch Loss:  0.17996900585981515
# 	Average Validation Count Epoch Loss:  0.21465394359368545
# Train Epoch: 4 [0/3150 (0%)]	Loss: 0.116092
# Train Epoch: 4 [750/3150 (12%)]	Loss: 0.124734
# Train Epoch: 4 [1500/3150 (24%)]	Loss: 0.108108
# Train Epoch: 4 [2250/3150 (36%)]	Loss: 0.065726
# Train Epoch: 4 [3000/3150 (48%)]	Loss: 0.063539
#
# Average Train Epoch Loss:  0.08588231209488142
# Average Train Map Loss:  0.08562731010218462
# Average Train Count Epoch Loss:  0.11112743679966246
# 	Average Validation Epoch Loss:  0.061436234042048454
# 	Average Validation Map Epoch Loss:  0.061165763351779714
# 	Average Validation Count Epoch Loss:  0.08821275171179038
# Train Epoch: 5 [0/3150 (0%)]	Loss: 0.059141
# Train Epoch: 5 [750/3150 (12%)]	Loss: 0.058847
# Train Epoch: 5 [1500/3150 (24%)]	Loss: 0.051599
# Train Epoch: 5 [2250/3150 (36%)]	Loss: 0.053202
# Train Epoch: 5 [3000/3150 (48%)]	Loss: 0.048246
#
# Average Train Epoch Loss:  0.05833576213391054
# Average Train Map Loss:  0.058058704063296315
# Average Train Count Epoch Loss:  0.08576448109178315
# 	Average Validation Epoch Loss:  0.0465088806186731
# 	Average Validation Map Epoch Loss:  0.04621730114404972
# 	Average Validation Count Epoch Loss:  0.07537522740088977
# Train Epoch: 6 [0/3150 (0%)]	Loss: 0.051692
# Train Epoch: 6 [750/3150 (12%)]	Loss: 0.049233
# Train Epoch: 6 [1500/3150 (24%)]	Loss: 0.045055
# Train Epoch: 6 [2250/3150 (36%)]	Loss: 0.048236
# Train Epoch: 6 [3000/3150 (48%)]	Loss: 0.041559
#
# Average Train Epoch Loss:  0.044521650938051084
# Average Train Map Loss:  0.04423006311768577
# Average Train Count Epoch Loss:  0.07338880492108209
# 	Average Validation Epoch Loss:  0.03596864748173035
# 	Average Validation Map Epoch Loss:  0.03566321372412718
# 	Average Validation Count Epoch Loss:  0.06620657386688086
# Train Epoch: 7 [0/3150 (0%)]	Loss: 0.038060
# Train Epoch: 7 [750/3150 (12%)]	Loss: 0.034279
# Train Epoch: 7 [1500/3150 (24%)]	Loss: 0.033375
# Train Epoch: 7 [2250/3150 (36%)]	Loss: 0.045442
# Train Epoch: 7 [3000/3150 (48%)]	Loss: 0.035605
#
# Average Train Epoch Loss:  0.03743767360491412
# Average Train Map Loss:  0.037141401835140725
# Average Train Count Epoch Loss:  0.06676854764421782
# 	Average Validation Epoch Loss:  0.03241979552862736
# 	Average Validation Map Epoch Loss:  0.0321095809340477
# 	Average Validation Count Epoch Loss:  0.06313099855413803
# Train Epoch: 8 [0/3150 (0%)]	Loss: 0.030162
# Train Epoch: 8 [750/3150 (12%)]	Loss: 0.031444
# Train Epoch: 8 [1500/3150 (24%)]	Loss: 0.033639
# Train Epoch: 8 [2250/3150 (36%)]	Loss: 0.028199
# Train Epoch: 8 [3000/3150 (48%)]	Loss: 0.032980
#
# Average Train Epoch Loss:  0.03331651821555126
# Average Train Map Loss:  0.03301537497235196
# Average Train Count Epoch Loss:  0.06312966804419246
# 	Average Validation Epoch Loss:  0.028303252533078194
# 	Average Validation Map Epoch Loss:  0.027986198663711548
# 	Average Validation Count Epoch Loss:  0.05969150880208382
# Train Epoch: 9 [0/3150 (0%)]	Loss: 0.036928
# Train Epoch: 9 [750/3150 (12%)]	Loss: 0.033285
# Train Epoch: 9 [1500/3150 (24%)]	Loss: 0.033855
# Train Epoch: 9 [2250/3150 (36%)]	Loss: 0.030513
# Train Epoch: 9 [3000/3150 (48%)]	Loss: 0.030415
#
# Average Train Epoch Loss:  0.030383507525991827
# Average Train Map Loss:  0.030080695166474297
# Average Train Count Epoch Loss:  0.06036191100165957
# 	Average Validation Epoch Loss:  0.026335658935400155
# 	Average Validation Map Epoch Loss:  0.026020306520737134
# 	Average Validation Count Epoch Loss:  0.057555549419843234
# Train Epoch: 10 [0/3150 (0%)]	Loss: 0.030410
# Train Epoch: 10 [750/3150 (12%)]	Loss: 0.029225
# Train Epoch: 10 [1500/3150 (24%)]	Loss: 0.029748
# Train Epoch: 10 [2250/3150 (36%)]	Loss: 0.028789
# Train Epoch: 10 [3000/3150 (48%)]	Loss: 0.023953
#
# Average Train Epoch Loss:  0.028595795118737787
# Average Train Map Loss:  0.02828991608250709
# Average Train Count Epoch Loss:  0.0588777947638716
# 	Average Validation Epoch Loss:  0.026024813190675698
# 	Average Validation Map Epoch Loss:  0.02570926218938369
# 	Average Validation Count Epoch Loss:  0.05726433903552019
# Train Epoch: 11 [0/3150 (0%)]	Loss: 0.028509
# Train Epoch: 11 [750/3150 (12%)]	Loss: 0.026546
# Train Epoch: 11 [1500/3150 (24%)]	Loss: 0.027888
# Train Epoch: 11 [2250/3150 (36%)]	Loss: 0.023877
# Train Epoch: 11 [3000/3150 (48%)]	Loss: 0.026943
#
# Average Train Epoch Loss:  0.027307728553811708
# Average Train Map Loss:  0.027002045618636266
# Average Train Count Epoch Loss:  0.05757031816811789
# 	Average Validation Epoch Loss:  0.024760822407328166
# 	Average Validation Map Epoch Loss:  0.02444659280948914
# 	Average Validation Count Epoch Loss:  0.05586951168683859
# Train Epoch: 12 [0/3150 (0%)]	Loss: 0.026197
# Train Epoch: 12 [750/3150 (12%)]	Loss: 0.023885
# Train Epoch: 12 [1500/3150 (24%)]	Loss: 0.026595
# Train Epoch: 12 [2250/3150 (36%)]	Loss: 0.027900
# Train Epoch: 12 [3000/3150 (48%)]	Loss: 0.025580
#
# Average Train Epoch Loss:  0.026251420919739064
# Average Train Map Loss:  0.02594486286952382
# Average Train Count Epoch Loss:  0.056600640891563324
# 	Average Validation Epoch Loss:  0.02354779402510478
# 	Average Validation Map Epoch Loss:  0.023241157930057783
# 	Average Validation Count Epoch Loss:  0.05390473913687926
# Train Epoch: 13 [0/3150 (0%)]	Loss: 0.024255
# Train Epoch: 13 [750/3150 (12%)]	Loss: 0.027087
# Train Epoch: 13 [1500/3150 (24%)]	Loss: 0.020940
# Train Epoch: 13 [2250/3150 (36%)]	Loss: 0.023453
# Train Epoch: 13 [3000/3150 (48%)]	Loss: 0.022210
#
# Average Train Epoch Loss:  0.025123472130369574
# Average Train Map Loss:  0.02481622936292773
# Average Train Count Epoch Loss:  0.05554047840691748
# 	Average Validation Epoch Loss:  0.022669750552337904
# 	Average Validation Map Epoch Loss:  0.022361217066645622
# 	Average Validation Count Epoch Loss:  0.05321452365471767
# Train Epoch: 14 [0/3150 (0%)]	Loss: 0.025296
# Train Epoch: 14 [750/3150 (12%)]	Loss: 0.022233
# Train Epoch: 14 [1500/3150 (24%)]	Loss: 0.023427
# Train Epoch: 14 [2250/3150 (36%)]	Loss: 0.023512
# Train Epoch: 14 [3000/3150 (48%)]	Loss: 0.025907
#
# Average Train Epoch Loss:  0.024287166366619723
# Average Train Map Loss:  0.023981615377678758
# Average Train Count Epoch Loss:  0.054536699237568036
# 	Average Validation Epoch Loss:  0.02199677725394185
# 	Average Validation Map Epoch Loss:  0.0216944392483968
# 	Average Validation Count Epoch Loss:  0.05192822432861878
# Train Epoch: 15 [0/3150 (0%)]	Loss: 0.021178
# Train Epoch: 15 [750/3150 (12%)]	Loss: 0.024434
# Train Epoch: 15 [1500/3150 (24%)]	Loss: 0.018553
# Train Epoch: 15 [2250/3150 (36%)]	Loss: 0.023283
# Train Epoch: 15 [3000/3150 (48%)]	Loss: 0.022393
#
# Average Train Epoch Loss:  0.02325481100096589
# Average Train Map Loss:  0.022958166444940226
# Average Train Count Epoch Loss:  0.05262260827280226
# 	Average Validation Epoch Loss:  0.02097686193883419
# 	Average Validation Map Epoch Loss:  0.020689392677293375
# 	Average Validation Count Epoch Loss:  0.049436333804176405
# Train Epoch: 16 [0/3150 (0%)]	Loss: 0.023754
# Train Epoch: 16 [750/3150 (12%)]	Loss: 0.019967
# Train Epoch: 16 [1500/3150 (24%)]	Loss: 0.022231
# Train Epoch: 16 [2250/3150 (36%)]	Loss: 0.021897
# Train Epoch: 16 [3000/3150 (48%)]	Loss: 0.020169
#
# Average Train Epoch Loss:  0.022462705052679492
# Average Train Map Loss:  0.02216938967328696
# Average Train Count Epoch Loss:  0.05150091318147523
# 	Average Validation Epoch Loss:  0.019813000260350797
# 	Average Validation Map Epoch Loss:  0.019525525983996116
# 	Average Validation Count Epoch Loss:  0.048272930372219816
# Train Epoch: 17 [0/3150 (0%)]	Loss: 0.020865
# Train Epoch: 17 [750/3150 (12%)]	Loss: 0.025206
# Train Epoch: 17 [1500/3150 (24%)]	Loss: 0.020785
# Train Epoch: 17 [2250/3150 (36%)]	Loss: 0.020505
# Train Epoch: 17 [3000/3150 (48%)]	Loss: 0.016645
#
# Average Train Epoch Loss:  0.02190327544120096
# Average Train Map Loss:  0.021609432538527817
# Average Train Count Epoch Loss:  0.05099370435235046
# 	Average Validation Epoch Loss:  0.021326496409109004
# 	Average Validation Map Epoch Loss:  0.021034402271302845
# 	Average Validation Count Epoch Loss:  0.05024380566409001
# Train Epoch: 18 [0/3150 (0%)]	Loss: 0.019955
# Train Epoch: 18 [750/3150 (12%)]	Loss: 0.020802
# Train Epoch: 18 [1500/3150 (24%)]	Loss: 0.021541
# Train Epoch: 18 [2250/3150 (36%)]	Loss: 0.018734
# Train Epoch: 18 [3000/3150 (48%)]	Loss: 0.023635
#
# Average Train Epoch Loss:  0.021187778961445605
# Average Train Map Loss:  0.020895883338969377
# Average Train Count Epoch Loss:  0.05008542198865187
# 	Average Validation Epoch Loss:  0.01925067610752124
# 	Average Validation Map Epoch Loss:  0.018949480584034555
# 	Average Validation Count Epoch Loss:  0.04906902018074806
# Train Epoch: 19 [0/3150 (0%)]	Loss: 0.022624
# Train Epoch: 19 [750/3150 (12%)]	Loss: 0.024737
# Train Epoch: 19 [1500/3150 (24%)]	Loss: 0.019285
# Train Epoch: 19 [2250/3150 (36%)]	Loss: 0.023566
# Train Epoch: 19 [3000/3150 (48%)]	Loss: 0.021379
#
# Average Train Epoch Loss:  0.020507731483805747
# Average Train Map Loss:  0.02021943273554955
# Average Train Count Epoch Loss:  0.04904929163555304
# 	Average Validation Epoch Loss:  0.019722290372905824
# 	Average Validation Map Epoch Loss:  0.019429212221159384
# 	Average Validation Count Epoch Loss:  0.04873701485876854
# Train Epoch: 20 [0/3150 (0%)]	Loss: 0.019442
# Train Epoch: 20 [750/3150 (12%)]	Loss: 0.021702
# Train Epoch: 20 [1500/3150 (24%)]	Loss: 0.022292
# Train Epoch: 20 [2250/3150 (36%)]	Loss: 0.019405
# Train Epoch: 20 [3000/3150 (48%)]	Loss: 0.018718
#
# Average Train Epoch Loss:  0.019838719815015792
# Average Train Map Loss:  0.019551531163354716
# Average Train Count Epoch Loss:  0.04827037780057816
# 	Average Validation Epoch Loss:  0.018728642616994105
# 	Average Validation Map Epoch Loss:  0.018433111397406228
# 	Average Validation Count Epoch Loss:  0.047986190766096115
# Train Epoch: 21 [0/3150 (0%)]	Loss: 0.016070
# Train Epoch: 21 [750/3150 (12%)]	Loss: 0.018372
# Train Epoch: 21 [1500/3150 (24%)]	Loss: 0.018285
# Train Epoch: 21 [2250/3150 (36%)]	Loss: 0.020074
# Train Epoch: 21 [3000/3150 (48%)]	Loss: 0.024470
#
# Average Train Epoch Loss:  0.019216852741582052
# Average Train Map Loss:  0.01892805607723338
# Average Train Count Epoch Loss:  0.047807702493099936
# 	Average Validation Epoch Loss:  0.018175706804658357
# 	Average Validation Map Epoch Loss:  0.0178718026011036
# 	Average Validation Count Epoch Loss:  0.048262202682403416
# Train Epoch: 22 [0/3150 (0%)]	Loss: 0.017605
# Train Epoch: 22 [750/3150 (12%)]	Loss: 0.016608
# Train Epoch: 22 [1500/3150 (24%)]	Loss: 0.021224
# Train Epoch: 22 [2250/3150 (36%)]	Loss: 0.021818
# Train Epoch: 22 [3000/3150 (48%)]	Loss: 0.020759
#
# Average Train Epoch Loss:  0.018670359524410395
# Average Train Map Loss:  0.018384594860531036
# Average Train Count Epoch Loss:  0.04696103715825649
# 	Average Validation Epoch Loss:  0.017428739103846826
# 	Average Validation Map Epoch Loss:  0.01713501662015915
# 	Average Validation Count Epoch Loss:  0.04650724664903604
# Train Epoch: 23 [0/3150 (0%)]	Loss: 0.015967
# Train Epoch: 23 [750/3150 (12%)]	Loss: 0.017506
# Train Epoch: 23 [1500/3150 (24%)]	Loss: 0.016876
# Train Epoch: 23 [2250/3150 (36%)]	Loss: 0.019076
# Train Epoch: 23 [3000/3150 (48%)]	Loss: 0.014917
#
# Average Train Epoch Loss:  0.018149662567746073
# Average Train Map Loss:  0.017863692777852217
# Average Train Count Epoch Loss:  0.046460659110120366
# 	Average Validation Epoch Loss:  0.017919810954481363
# 	Average Validation Map Epoch Loss:  0.017618654654003106
# 	Average Validation Count Epoch Loss:  0.047734258839717277
# Train Epoch: 24 [0/3150 (0%)]	Loss: 0.021724
# Train Epoch: 24 [750/3150 (12%)]	Loss: 0.019914
# Train Epoch: 24 [1500/3150 (24%)]	Loss: 0.017137
# Train Epoch: 24 [2250/3150 (36%)]	Loss: 0.017914
# Train Epoch: 24 [3000/3150 (48%)]	Loss: 0.018207
#
# Average Train Epoch Loss:  0.01760573097549024
# Average Train Map Loss:  0.01731901844697339
# Average Train Count Epoch Loss:  0.04599026093880335
# 	Average Validation Epoch Loss:  0.01721204645358599
# 	Average Validation Map Epoch Loss:  0.016917762883867208
# 	Average Validation Count Epoch Loss:  0.04634609603537963
# Train Epoch: 25 [0/3150 (0%)]	Loss: 0.017674
# Train Epoch: 25 [750/3150 (12%)]	Loss: 0.019411
# Train Epoch: 25 [1500/3150 (24%)]	Loss: 0.015277
# Train Epoch: 25 [2250/3150 (36%)]	Loss: 0.017708
# Train Epoch: 25 [3000/3150 (48%)]	Loss: 0.015824
#
# Average Train Epoch Loss:  0.01704695454488198
# Average Train Map Loss:  0.016755051755656798
# Average Train Count Epoch Loss:  0.04594531249077547
# 	Average Validation Epoch Loss:  0.017415947531564877
# 	Average Validation Map Epoch Loss:  0.017118704326164264
# 	Average Validation Count Epoch Loss:  0.04684301164860909
# Train Epoch: 26 [0/3150 (0%)]	Loss: 0.018401
# Train Epoch: 26 [750/3150 (12%)]	Loss: 0.012279
# Train Epoch: 26 [1500/3150 (24%)]	Loss: 0.017697
# Train Epoch: 26 [2250/3150 (36%)]	Loss: 0.017425
# Train Epoch: 26 [3000/3150 (48%)]	Loss: 0.012804
#
# Average Train Epoch Loss:  0.016586313117295505
# Average Train Map Loss:  0.0162954835709007
# Average Train Count Epoch Loss:  0.045378428874980836
# 	Average Validation Epoch Loss:  0.017518530886333723
# 	Average Validation Map Epoch Loss:  0.017213029679484092
# 	Average Validation Count Epoch Loss:  0.0477631392960365
# Train Epoch: 27 [0/3150 (0%)]	Loss: 0.017565
# Train Epoch: 27 [750/3150 (12%)]	Loss: 0.013711
# Train Epoch: 27 [1500/3150 (24%)]	Loss: 0.013957
# Train Epoch: 27 [2250/3150 (36%)]	Loss: 0.014325
# Train Epoch: 27 [3000/3150 (48%)]	Loss: 0.011841
#
# Average Train Epoch Loss:  0.01610999671032741
# Average Train Map Loss:  0.015818834193937835
# Average Train Count Epoch Loss:  0.04493506857681842
# 	Average Validation Epoch Loss:  0.016849057283252478
# 	Average Validation Map Epoch Loss:  0.016545638692780182
# 	Average Validation Count Epoch Loss:  0.0468874923311747
# Train Epoch: 28 [0/3150 (0%)]	Loss: 0.016385
# Train Epoch: 28 [750/3150 (12%)]	Loss: 0.014532
# Train Epoch: 28 [1500/3150 (24%)]	Loss: 0.012507
# Train Epoch: 28 [2250/3150 (36%)]	Loss: 0.014691
# Train Epoch: 28 [3000/3150 (48%)]	Loss: 0.013203
#
# Average Train Epoch Loss:  0.015747795072162434
# Average Train Map Loss:  0.01545727098183263
# Average Train Count Epoch Loss:  0.044509662350728396
# 	Average Validation Epoch Loss:  0.01634070545864793
# 	Average Validation Map Epoch Loss:  0.016033821882536776
# 	Average Validation Count Epoch Loss:  0.046722150479371734
# Train Epoch: 29 [0/3150 (0%)]	Loss: 0.016403
# Train Epoch: 29 [750/3150 (12%)]	Loss: 0.010832
# Train Epoch: 29 [1500/3150 (24%)]	Loss: 0.016840
# Train Epoch: 29 [2250/3150 (36%)]	Loss: 0.016552
# Train Epoch: 29 [3000/3150 (48%)]	Loss: 0.014573
#
# Average Train Epoch Loss:  0.015196572700958876
# Average Train Map Loss:  0.014902583150459187
# Average Train Count Epoch Loss:  0.0443015231972649
# 	Average Validation Epoch Loss:  0.016483338012431677
# 	Average Validation Map Epoch Loss:  0.01617481068779643
# 	Average Validation Count Epoch Loss:  0.04702754791539449
# Train Epoch: 30 [0/3150 (0%)]	Loss: 0.019877
# Train Epoch: 30 [750/3150 (12%)]	Loss: 0.012044
# Train Epoch: 30 [1500/3150 (24%)]	Loss: 0.012647
# Train Epoch: 30 [2250/3150 (36%)]	Loss: 0.014683
# Train Epoch: 30 [3000/3150 (48%)]	Loss: 0.012872
#
# Average Train Epoch Loss:  0.014849595929540339
# Average Train Map Loss:  0.014554373436563071
# Average Train Count Epoch Loss:  0.04407660150456996
# 	Average Validation Epoch Loss:  0.01611664780200674
# 	Average Validation Map Epoch Loss:  0.015809185086534575
# 	Average Validation Count Epoch Loss:  0.04655545276518051
# Train Epoch: 31 [0/3150 (0%)]	Loss: 0.016020
# Train Epoch: 31 [750/3150 (12%)]	Loss: 0.011992
# Train Epoch: 31 [1500/3150 (24%)]	Loss: 0.013821
# Train Epoch: 31 [2250/3150 (36%)]	Loss: 0.013946
# Train Epoch: 31 [3000/3150 (48%)]	Loss: 0.014209
#
# Average Train Epoch Loss:  0.014337823460144656
# Average Train Map Loss:  0.014044174019779478
# Average Train Count Epoch Loss:  0.043409104450117975
# 	Average Validation Epoch Loss:  0.01626902908230057
# 	Average Validation Map Epoch Loss:  0.015963216348049734
# 	Average Validation Count Epoch Loss:  0.046544486800065406
# Train Epoch: 32 [0/3150 (0%)]	Loss: 0.010712
# Train Epoch: 32 [750/3150 (12%)]	Loss: 0.016805
# Train Epoch: 32 [1500/3150 (24%)]	Loss: 0.011719
# Train Epoch: 32 [2250/3150 (36%)]	Loss: 0.020033
# Train Epoch: 32 [3000/3150 (48%)]	Loss: 0.011619
#
# Average Train Epoch Loss:  0.013926376703949202
# Average Train Map Loss:  0.013629474508620443
# Average Train Count Epoch Loss:  0.043319685118538995
# 	Average Validation Epoch Loss:  0.015965026839134786
# 	Average Validation Map Epoch Loss:  0.01564027487228696
# 	Average Validation Count Epoch Loss:  0.04811546120506067
# Train Epoch: 33 [0/3150 (0%)]	Loss: 0.012386
# Train Epoch: 33 [750/3150 (12%)]	Loss: 0.016160
# Train Epoch: 33 [1500/3150 (24%)]	Loss: 0.011228
# Train Epoch: 33 [2250/3150 (36%)]	Loss: 0.010984
# Train Epoch: 33 [3000/3150 (48%)]	Loss: 0.010740
#
# Average Train Epoch Loss:  0.013541442151403143
# Average Train Map Loss:  0.013244409242733603
# Average Train Count Epoch Loss:  0.04294768965670041
# 	Average Validation Epoch Loss:  0.016352885366918948
# 	Average Validation Map Epoch Loss:  0.01603131049957413
# 	Average Validation Count Epoch Loss:  0.048188779646387465
# Train Epoch: 34 [0/3150 (0%)]	Loss: 0.009195
# Train Epoch: 34 [750/3150 (12%)]	Loss: 0.014464
# Train Epoch: 34 [1500/3150 (24%)]	Loss: 0.011971
# Train Epoch: 34 [2250/3150 (36%)]	Loss: 0.011120
# Train Epoch: 34 [3000/3150 (48%)]	Loss: 0.013606
#
# Average Train Epoch Loss:  0.01322499481251552
# Average Train Map Loss:  0.012926437847671054
# Average Train Count Epoch Loss:  0.04278212546237877
# 	Average Validation Epoch Loss:  0.01574052067903372
# 	Average Validation Map Epoch Loss:  0.015422171590706477
# 	Average Validation Count Epoch Loss:  0.04725707895480669
# Train Epoch: 35 [0/3150 (0%)]	Loss: 0.011562
# Train Epoch: 35 [750/3150 (12%)]	Loss: 0.011008
# Train Epoch: 35 [1500/3150 (24%)]	Loss: 0.011957
# Train Epoch: 35 [2250/3150 (36%)]	Loss: 0.013646
# Train Epoch: 35 [3000/3150 (48%)]	Loss: 0.011862
#
# Average Train Epoch Loss:  0.012786269542716798
# Average Train Map Loss:  0.01248840641762529
# Average Train Count Epoch Loss:  0.04227470413205169
# 	Average Validation Epoch Loss:  0.015883274985334046
# 	Average Validation Map Epoch Loss:  0.0155483611787741
# 	Average Validation Count Epoch Loss:  0.049039734670749076
# Train Epoch: 36 [0/3150 (0%)]	Loss: 0.012191
# Train Epoch: 36 [750/3150 (12%)]	Loss: 0.010206
# Train Epoch: 36 [1500/3150 (24%)]	Loss: 0.010460
# Train Epoch: 36 [2250/3150 (36%)]	Loss: 0.014056
# Train Epoch: 36 [3000/3150 (48%)]	Loss: 0.014428
#
# Average Train Epoch Loss:  0.012562552453683956
# Average Train Map Loss:  0.012264473618762125
# Average Train Count Epoch Loss:  0.04207234599051021
# 	Average Validation Epoch Loss:  0.015475027334804718
# 	Average Validation Map Epoch Loss:  0.015154829463706566
# 	Average Validation Count Epoch Loss:  0.04717460847817934
# Train Epoch: 37 [0/3150 (0%)]	Loss: 0.011664
# Train Epoch: 37 [750/3150 (12%)]	Loss: 0.012750
# Train Epoch: 37 [1500/3150 (24%)]	Loss: 0.014365
# Train Epoch: 37 [2250/3150 (36%)]	Loss: 0.011896
# Train Epoch: 37 [3000/3150 (48%)]	Loss: 0.012339
#
# Average Train Epoch Loss:  0.012276959162028063
# Average Train Map Loss:  0.011977339433949618
# Average Train Count Epoch Loss:  0.04193930447633777
# 	Average Validation Epoch Loss:  0.015773467146433316
# 	Average Validation Map Epoch Loss:  0.01543420205752437
# 	Average Validation Count Epoch Loss:  0.049360689062338606
# Train Epoch: 38 [0/3150 (0%)]	Loss: 0.012487
# Train Epoch: 38 [750/3150 (12%)]	Loss: 0.010944
# Train Epoch: 38 [1500/3150 (24%)]	Loss: 0.011108
# Train Epoch: 38 [2250/3150 (36%)]	Loss: 0.014936
# Train Epoch: 38 [3000/3150 (48%)]	Loss: 0.012359
#
# Average Train Epoch Loss:  0.012032740028752457
# Average Train Map Loss:  0.01173427738249302
# Average Train Count Epoch Loss:  0.041580531196225255
# 	Average Validation Epoch Loss:  0.01545267254830553
# 	Average Validation Map Epoch Loss:  0.01511663499359901
# 	Average Validation Count Epoch Loss:  0.04872037498996808
# Train Epoch: 39 [0/3150 (0%)]	Loss: 0.010143
# Train Epoch: 39 [750/3150 (12%)]	Loss: 0.012000
# Train Epoch: 39 [1500/3150 (24%)]	Loss: 0.012789
# Train Epoch: 39 [2250/3150 (36%)]	Loss: 0.016471
# Train Epoch: 39 [3000/3150 (48%)]	Loss: 0.013552
#
# Average Train Epoch Loss:  0.01175089871865653
# Average Train Map Loss:  0.01145076041686393
# Average Train Count Epoch Loss:  0.041464582174306826
# 	Average Validation Epoch Loss:  0.014885062960764537
# 	Average Validation Map Epoch Loss:  0.01453716723391643
# 	Average Validation Count Epoch Loss:  0.04932673318454853
# Train Epoch: 40 [0/3150 (0%)]	Loss: 0.009501
# Train Epoch: 40 [750/3150 (12%)]	Loss: 0.010314
# Train Epoch: 40 [1500/3150 (24%)]	Loss: 0.009294
# Train Epoch: 40 [2250/3150 (36%)]	Loss: 0.011671
# Train Epoch: 40 [3000/3150 (48%)]	Loss: 0.012113
#
# Average Train Epoch Loss:  0.011480793379069794
# Average Train Map Loss:  0.01118345842474983
# Average Train Count Epoch Loss:  0.040916942929228144
# 	Average Validation Epoch Loss:  0.015469845455999557
# 	Average Validation Map Epoch Loss:  0.015129305995427646
# 	Average Validation Count Epoch Loss:  0.04918323930066366
# Train Epoch: 41 [0/3150 (0%)]	Loss: 0.009643
# Train Epoch: 41 [750/3150 (12%)]	Loss: 0.012094
# Train Epoch: 41 [1500/3150 (24%)]	Loss: 0.012209
# Train Epoch: 41 [2250/3150 (36%)]	Loss: 0.008393
# Train Epoch: 41 [3000/3150 (48%)]	Loss: 0.013959
#
# Average Train Epoch Loss:  0.011322061245196632
# Average Train Map Loss:  0.011022865466241325
# Average Train Count Epoch Loss:  0.040942434327942985
# 	Average Validation Epoch Loss:  0.016334429347457793
# 	Average Validation Map Epoch Loss:  0.016000740659924653
# 	Average Validation Count Epoch Loss:  0.049369616577258475
# Train Epoch: 42 [0/3150 (0%)]	Loss: 0.009302
# Train Epoch: 42 [750/3150 (12%)]	Loss: 0.011018
# Train Epoch: 42 [1500/3150 (24%)]	Loss: 0.010741
# Train Epoch: 42 [2250/3150 (36%)]	Loss: 0.011922
# Train Epoch: 42 [3000/3150 (48%)]	Loss: 0.012318
#
# Average Train Epoch Loss:  0.010992374838817688
# Average Train Map Loss:  0.01069190193721581
# Average Train Count Epoch Loss:  0.04073918537192402
# 	Average Validation Epoch Loss:  0.014970937313941808
# 	Average Validation Map Epoch Loss:  0.014634173900748674
# 	Average Validation Count Epoch Loss:  0.0483105076620212
# Train Epoch: 43 [0/3150 (0%)]	Loss: 0.009480
# Train Epoch: 43 [750/3150 (12%)]	Loss: 0.010952
# Train Epoch: 43 [1500/3150 (24%)]	Loss: 0.015243
# Train Epoch: 43 [2250/3150 (36%)]	Loss: 0.011211
# Train Epoch: 43 [3000/3150 (48%)]	Loss: 0.008245
#
# Average Train Epoch Loss:  0.010858428580242963
# Average Train Map Loss:  0.010558418262129029
# Average Train Count Epoch Loss:  0.0405594434234358
# 	Average Validation Epoch Loss:  0.015815746433173235
# 	Average Validation Map Epoch Loss:  0.015499827057982866
# 	Average Validation Count Epoch Loss:  0.04709175286384729
# Train Epoch: 44 [0/3150 (0%)]	Loss: 0.010523
# Train Epoch: 44 [750/3150 (12%)]	Loss: 0.009781
# Train Epoch: 44 [1500/3150 (24%)]	Loss: 0.012306
# Train Epoch: 44 [2250/3150 (36%)]	Loss: 0.010618
# Train Epoch: 44 [3000/3150 (48%)]	Loss: 0.011106
# Average Train Epoch Loss:  0.010614652905081
# Average Train Map Loss:  0.010316259340782251
# Average Train Count Epoch Loss:  0.0401556061314685
# 	Average Validation Epoch Loss:  0.015423502593945999
# 	Average Validation Map Epoch Loss:  0.015098910742940811
# 	Average Validation Count Epoch Loss:  0.04755806665007885
# Train Epoch: 45 [0/3150 (0%)]	Loss: 0.011355
# Train Epoch: 45 [750/3150 (12%)]	Loss: 0.013396
# Train Epoch: 45 [1500/3150 (24%)]	Loss: 0.012195
# Train Epoch: 45 [2250/3150 (36%)]	Loss: 0.012599
# Train Epoch: 45 [3000/3150 (48%)]	Loss: 0.009082
#
# Average Train Epoch Loss:  0.01046174431352743
# Average Train Map Loss:  0.010161428734482754
# Average Train Count Epoch Loss:  0.04019297791556233
# 	Average Validation Epoch Loss:  0.014682971944029514
# 	Average Validation Map Epoch Loss:  0.014324747778188724
# 	Average Validation Count Epoch Loss:  0.05014715415353958
# Train Epoch: 46 [0/3150 (0%)]	Loss: 0.007935
# Train Epoch: 46 [750/3150 (12%)]	Loss: 0.007706
# Train Epoch: 46 [1500/3150 (24%)]	Loss: 0.012418
# Train Epoch: 46 [2250/3150 (36%)]	Loss: 0.010613
# Train Epoch: 46 [3000/3150 (48%)]	Loss: 0.011417
#
# Average Train Epoch Loss:  0.010197486393597154
# Average Train Map Loss:  0.009897387539967894
# Average Train Count Epoch Loss:  0.03990726830171687
# 	Average Validation Epoch Loss:  0.015394221489819197
# 	Average Validation Map Epoch Loss:  0.015073334260915335
# 	Average Validation Count Epoch Loss:  0.047162034190618075
# Train Epoch: 47 [0/3150 (0%)]	Loss: 0.009261
# Train Epoch: 47 [750/3150 (12%)]	Loss: 0.008474
# Train Epoch: 47 [1500/3150 (24%)]	Loss: 0.011603
# Train Epoch: 47 [2250/3150 (36%)]	Loss: 0.008648
# Train Epoch: 47 [3000/3150 (48%)]	Loss: 0.016112
#
# Average Train Epoch Loss:  0.009977151976809616
# Average Train Map Loss:  0.009675799649474875
# Average Train Count Epoch Loss:  0.03981102648235503
# 	Average Validation Epoch Loss:  0.015426724289472286
# 	Average Validation Map Epoch Loss:  0.015093807811633898
# 	Average Validation Count Epoch Loss:  0.04838541536950148
# Train Epoch: 48 [0/3150 (0%)]	Loss: 0.010803
# Train Epoch: 48 [750/3150 (12%)]	Loss: 0.012431
# Train Epoch: 48 [1500/3150 (24%)]	Loss: 0.010562
# Train Epoch: 48 [2250/3150 (36%)]	Loss: 0.010363
# Train Epoch: 48 [3000/3150 (48%)]	Loss: 0.007858
#
# Average Train Epoch Loss:  0.009854193907674579
# Average Train Map Loss:  0.009556492511183023
# Average Train Count Epoch Loss:  0.03932662511333113
# 	Average Validation Epoch Loss:  0.015118907671421766
# 	Average Validation Map Epoch Loss:  0.014762278001468915
# 	Average Validation Count Epoch Loss:  0.050425244781833425
# Train Epoch: 49 [0/3150 (0%)]	Loss: 0.010842
# Train Epoch: 49 [750/3150 (12%)]	Loss: 0.008366
# Train Epoch: 49 [1500/3150 (24%)]	Loss: 0.007687
# Train Epoch: 49 [2250/3150 (36%)]	Loss: 0.007840
# Train Epoch: 49 [3000/3150 (48%)]	Loss: 0.010106
#
# Average Train Epoch Loss:  0.009672315485243286
# Average Train Map Loss:  0.009375808871395531
# Average Train Count Epoch Loss:  0.03902646596765234
# 	Average Validation Epoch Loss:  0.014998429741423864
# 	Average Validation Map Epoch Loss:  0.014655999516924987
# 	Average Validation Count Epoch Loss:  0.04889902314887597
# Train Epoch: 50 [0/3150 (0%)]	Loss: 0.010933
# Train Epoch: 50 [750/3150 (12%)]	Loss: 0.008564
# Train Epoch: 50 [1500/3150 (24%)]	Loss: 0.010421
# Train Epoch: 50 [2250/3150 (36%)]	Loss: 0.010928
# Train Epoch: 50 [3000/3150 (48%)]	Loss: 0.008262
#
# Average Train Epoch Loss:  0.00945499429390544
# Average Train Map Loss:  0.00915773219340259
# Average Train Count Epoch Loss:  0.03888393224527439
# 	Average Validation Epoch Loss:  0.015494585431252535
# 	Average Validation Map Epoch Loss:  0.015166612521100502
# 	Average Validation Count Epoch Loss:  0.047963898772230514
# Train Epoch: 51 [0/3150 (0%)]	Loss: 0.007577
# Train Epoch: 51 [750/3150 (12%)]	Loss: 0.009592
# Train Epoch: 51 [1500/3150 (24%)]	Loss: 0.008844
# Train Epoch: 51 [2250/3150 (36%)]	Loss: 0.007859
# Train Epoch: 51 [3000/3150 (48%)]	Loss: 0.008407
#
# Average Train Epoch Loss:  0.00939711484658931
# Average Train Map Loss:  0.009101713867858052
# Average Train Count Epoch Loss:  0.03864180075802973
# 	Average Validation Epoch Loss:  0.014858817681670189
# 	Average Validation Map Epoch Loss:  0.014510871161921667
# 	Average Validation Count Epoch Loss:  0.04930552725608532
# Train Epoch: 52 [0/3150 (0%)]	Loss: 0.010081
# Train Epoch: 52 [750/3150 (12%)]	Loss: 0.010676
# Train Epoch: 52 [1500/3150 (24%)]	Loss: 0.012080
# Train Epoch: 52 [2250/3150 (36%)]	Loss: 0.008113
# Train Epoch: 52 [3000/3150 (48%)]	Loss: 0.007578
#
# Average Train Epoch Loss:  0.009184416618552946
# Average Train Map Loss:  0.008888786408074554
# Average Train Count Epoch Loss:  0.038451802065329894
# 	Average Validation Epoch Loss:  0.015078679336091647
# 	Average Validation Map Epoch Loss:  0.01471774928415051
# 	Average Validation Count Epoch Loss:  0.05081074469937728
# Train Epoch: 53 [0/3150 (0%)]	Loss: 0.008225
# Train Epoch: 53 [750/3150 (12%)]	Loss: 0.011929
# Train Epoch: 53 [1500/3150 (24%)]	Loss: 0.010675
# Train Epoch: 53 [2250/3150 (36%)]	Loss: 0.009853
# Train Epoch: 53 [3000/3150 (48%)]	Loss: 0.008571
#
# Average Train Epoch Loss:  0.00916148391330526
# Average Train Map Loss:  0.008865067524658073
# Average Train Count Epoch Loss:  0.03850669749968109
# 	Average Validation Epoch Loss:  0.016509322342104636
# 	Average Validation Map Epoch Loss:  0.016170755458565857
# 	Average Validation Count Epoch Loss:  0.05002743965731217
# Train Epoch: 54 [0/3150 (0%)]	Loss: 0.008832
# Train Epoch: 54 [750/3150 (12%)]	Loss: 0.007058
# Train Epoch: 54 [1500/3150 (24%)]	Loss: 0.011822
# Train Epoch: 54 [2250/3150 (36%)]	Loss: 0.008550
# Train Epoch: 54 [3000/3150 (48%)]	Loss: 0.008619
#
# Average Train Epoch Loss:  0.008909362503549173
# Average Train Map Loss:  0.008620680119132711
# Average Train Count Epoch Loss:  0.037488911948388534
# 	Average Validation Epoch Loss:  0.015297854856516305
# 	Average Validation Map Epoch Loss:  0.014953570977713052
# 	Average Validation Count Epoch Loss:  0.0493819283751341
# Train Epoch: 55 [0/3150 (0%)]	Loss: 0.007395
# Train Epoch: 55 [750/3150 (12%)]	Loss: 0.008686
# Train Epoch: 55 [1500/3150 (24%)]	Loss: 0.007832
# Train Epoch: 55 [2250/3150 (36%)]	Loss: 0.010564
# Train Epoch: 55 [3000/3150 (48%)]	Loss: 0.010816
#
# Average Train Epoch Loss:  0.008867962081872282
# Average Train Map Loss:  0.008576932973006652
# Average Train Count Epoch Loss:  0.03767983557745105
# 	Average Validation Epoch Loss:  0.016448377559964474
# 	Average Validation Map Epoch Loss:  0.016108682916428033
# 	Average Validation Count Epoch Loss:  0.05007812710335621
# Train Epoch: 56 [0/3150 (0%)]	Loss: 0.008150
# Train Epoch: 56 [750/3150 (12%)]	Loss: 0.009635
# Train Epoch: 56 [1500/3150 (24%)]	Loss: 0.010436
# Train Epoch: 56 [2250/3150 (36%)]	Loss: 0.006917
# Train Epoch: 56 [3000/3150 (48%)]	Loss: 0.008160
#
# Average Train Epoch Loss:  0.008725685606311475
# Average Train Map Loss:  0.008436024370825006
# Average Train Count Epoch Loss:  0.03740213932026
# 	Average Validation Epoch Loss:  0.015495627043912044
# 	Average Validation Map Epoch Loss:  0.015152178024156736
# 	Average Validation Count Epoch Loss:  0.04949708540852253
# Train Epoch: 57 [0/3150 (0%)]	Loss: 0.007612
# Train Epoch: 57 [750/3150 (12%)]	Loss: 0.006961
# Train Epoch: 57 [1500/3150 (24%)]	Loss: 0.007256
# Train Epoch: 57 [2250/3150 (36%)]	Loss: 0.008911
# Train Epoch: 57 [3000/3150 (48%)]	Loss: 0.013618
#
# Average Train Epoch Loss:  0.008613763499029335
# Average Train Map Loss:  0.008324726413758029
# Average Train Count Epoch Loss:  0.03722842722421601
# 	Average Validation Epoch Loss:  0.01525701374675219
# 	Average Validation Map Epoch Loss:  0.01489801464888912
# 	Average Validation Count Epoch Loss:  0.05079791250710304
# Train Epoch: 58 [0/3150 (0%)]	Loss: 0.008045
# Train Epoch: 58 [750/3150 (12%)]	Loss: 0.008412
# Train Epoch: 58 [1500/3150 (24%)]	Loss: 0.007673
# Train Epoch: 58 [2250/3150 (36%)]	Loss: 0.008793
# Train Epoch: 58 [3000/3150 (48%)]	Loss: 0.010526
#
# Average Train Epoch Loss:  0.00846695580209295
# Average Train Map Loss:  0.008179648965597152
# Average Train Count Epoch Loss:  0.036910326237834634
# 	Average Validation Epoch Loss:  0.015143472450570418
# 	Average Validation Map Epoch Loss:  0.014796219801960083
# 	Average Validation Count Epoch Loss:  0.049521482263046965
# Train Epoch: 59 [0/3150 (0%)]	Loss: 0.005816
# Train Epoch: 59 [750/3150 (12%)]	Loss: 0.007286
# Train Epoch: 59 [1500/3150 (24%)]	Loss: 0.010030
# Train Epoch: 59 [2250/3150 (36%)]	Loss: 0.006209
# Train Epoch: 59 [3000/3150 (48%)]	Loss: 0.008636
#
# Average Train Epoch Loss:  0.0083886886436847
# Average Train Map Loss:  0.008101875359369886
# Average Train Count Epoch Loss:  0.03678319975733757
# 	Average Validation Epoch Loss:  0.015511237120685669
# 	Average Validation Map Epoch Loss:  0.015163509569202479
# 	Average Validation Count Epoch Loss:  0.04993624455080582
# Train Epoch: 60 [0/3150 (0%)]	Loss: 0.006317
# Train Epoch: 60 [750/3150 (12%)]	Loss: 0.008136
# Train Epoch: 60 [1500/3150 (24%)]	Loss: 0.007288
# Train Epoch: 60 [2250/3150 (36%)]	Loss: 0.009562
# Train Epoch: 60 [3000/3150 (48%)]	Loss: 0.009201
#
# Average Train Epoch Loss:  0.008217527200689629
# Average Train Map Loss:  0.007927228290853756
# Average Train Count Epoch Loss:  0.036957110118653096
# 	Average Validation Epoch Loss:  0.01590004298262871
# 	Average Validation Map Epoch Loss:  0.015552493994339155
# 	Average Validation Count Epoch Loss:  0.05030736241203088
# Train Epoch: 61 [0/3150 (0%)]	Loss: 0.007155
# Train Epoch: 61 [750/3150 (12%)]	Loss: 0.008281
# Train Epoch: 61 [1500/3150 (24%)]	Loss: 0.006788
# Train Epoch: 61 [2250/3150 (36%)]	Loss: 0.009632
# Train Epoch: 61 [3000/3150 (48%)]	Loss: 0.008286
#
# Average Train Epoch Loss:  0.008106862988677762
# Average Train Map Loss:  0.00781748808831686
# Average Train Count Epoch Loss:  0.036754972948914486
# 	Average Validation Epoch Loss:  0.01513330376921938
# 	Average Validation Map Epoch Loss:  0.014777306789675584
# 	Average Validation Count Epoch Loss:  0.050377001269505575
# Train Epoch: 62 [0/3150 (0%)]	Loss: 0.009129
# Train Epoch: 62 [750/3150 (12%)]	Loss: 0.007487
# Train Epoch: 62 [1500/3150 (24%)]	Loss: 0.007943
# Train Epoch: 62 [2250/3150 (36%)]	Loss: 0.007021
# Train Epoch: 62 [3000/3150 (48%)]	Loss: 0.009034
#
# Average Train Epoch Loss:  0.008082055058773784
# Average Train Map Loss:  0.007795538387394377
# Average Train Count Epoch Loss:  0.036447198990555034
# 	Average Validation Epoch Loss:  0.015316585078835487
# 	Average Validation Map Epoch Loss:  0.01496825349302246
# 	Average Validation Count Epoch Loss:  0.04980142457553974
# Train Epoch: 63 [0/3150 (0%)]	Loss: 0.007768
# Train Epoch: 63 [750/3150 (12%)]	Loss: 0.008334
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-4b1104e0bc03>", line 3, in <module>
#     train()
#   File "<ipython-input-32-dfa498045bed>", line 15, in train
#     for i, (sample, bbox_bins, road_maps, bbs, target_count, _) in enumerate(train_loader):
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 345, in __next__
#     data = self._next_data()
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 841, in _next_data
#     idx, data = self._get_data()
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 808, in _get_data
#     success, data = self._try_get_data()
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 761, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vr1059/py3.6.3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 1438, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 736, in getmodule
#     f = getabsfile(module)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 705, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/share/apps/python3/3.6.3/intel/lib/python3.6/inspect.py", line 690, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/vr1059/py3.6.3/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
# 0.01456

# 0.0143
